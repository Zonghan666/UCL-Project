# %% [markdown]
# <!---
# Latex Macros
# -->
# $$
# \newcommand{\bar}{\,|\,}
# \newcommand{\Xs}{\mathcal{X}}
# \newcommand{\Ys}{\mathcal{Y}}
# \newcommand{\y}{\mathbf{y}}
# \newcommand{\weights}{\mathbf{w}}
# \newcommand{\balpha}{\boldsymbol{\alpha}}
# \newcommand{\bbeta}{\boldsymbol{\beta}}
# \newcommand{\aligns}{\mathbf{a}}
# \newcommand{\align}{a}
# \newcommand{\source}{\mathbf{s}}
# \newcommand{\target}{\mathbf{t}}
# \newcommand{\ssource}{s}
# \newcommand{\starget}{t}
# \newcommand{\repr}{\mathbf{f}}
# \newcommand{\repry}{\mathbf{g}}
# \newcommand{\x}{\mathbf{x}}
# \newcommand{\prob}{p}
# \newcommand{\vocab}{V}
# \newcommand{\params}{\boldsymbol{\theta}}
# \newcommand{\param}{\theta}
# \DeclareMathOperator{\perplexity}{PP}
# \DeclareMathOperator{\argmax}{argmax}
# \DeclareMathOperator{\argmin}{argmin}
# \newcommand{\train}{\mathcal{D}}
# \newcommand{\counts}[2]{\#_{#1}(#2) }
# \newcommand{\length}[1]{\text{length}(#1) }
# \newcommand{\indi}{\mathbb{I}}
# $$

# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Introduction
#
# In the last assignment, you will apply deep learning methods to solve a particular story understanding problem. Automatic understanding of stories is an important task in natural language understanding [[1]](http://anthology.aclweb.org/D/D13/D13-1020.pdf). Specifically, you will develop a model that given a sequence of sentences learns to sort these sentence in order to yield a coherent story [[2]](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/06/short-commonsense-stories.pdf). This sounds (and to an extent is) trivial for humans, however it is quite a difficult task for machines as it involves commonsense knowledge and temporal understanding.

# %% [markdown]
# ## Goal
#
# You are given a dataset of 45502 instances, each consisting of 5 sentences. Your system needs to ouput a sequence of numbers which represent the predicted order of these sentences. For example, given a story:
#
#     He went to the store.
#     He found a lamp he liked.
#     He bought the lamp.
#     Jan decided to get a new lamp.
#     Jan's lamp broke.
#
# your system needs to provide an answer in the following form:
#
#     2	3	4	1	0
#
# where the numbers correspond to the zero-based index of each sentence in the correctly ordered story. So "`2`" for "`He went to the store.`" means that this sentence should come 3rd in the correctly ordered target story. In this particular example, this order of indices corresponds to the following target story:
#
#     Jan's lamp broke.
#     Jan decided to get a new lamp.
#     He went to the store.
#     He found a lamp he liked.
#     He bought the lamp.

# %% [markdown]
# ## Resources
#
# To develop your model(s), we provide a training and a development datasets. The test dataset will be held out, and we will use it to evaluate your models. The test set is coming from the same task distribution, and you don't need to expect drastic changes in it.
#
# You will use [TensorFlow](https://www.tensorflow.org/) to build a deep learning model for the task. We provide a very crude system which solves the task with a low accuracy, and a set of additional functions you will have to use to save and load the model you create so that we can run it.
#
# As we have to run the notebooks of each submission, and as deep learning models take long time to train, your notebook **NEEDS** to conform to the following requirements:
# * You **NEED** to run your parameter optimisation offline, and provide your final model saved by using the provided function
# * The maximum size of a zip file you can upload to moodle is 160MB. We will **NOT** allow submissions larger than that.
# * We do not have time to train your models from scratch! You **NEED** to provide the full code you used for the training of your model, but by all means you **CANNOT** call the training method in the notebook you will send to us.
# * We will run these notebooks automatically. If your notebook runs the training procedure, in addition to loading the model, and we need to edit your code to stop the training, you will be penalised with **-20 points**.
# * If you do not provide a pretrained model, and rely on training your model on our machines, you will get **0 points**.
# * Your submissions will be tested on the stat-nlp-book Docker image to ensure that it does not have any dependencies outside of those that we provide. If your submission fails to adhere to this requirement, you will get **0 points**.
#
# Running time and memory issues:
# * We have tested a possible solution on a mid-2014 MacBook Pro, and a few epochs of the model run in less than 3min. Thus it is possible to train a model on the data in reasonable time. However, be aware that you will need to run these models many times over, for a larger number of epochs (more elaborate models, trained on much larger datasets can train for weeks! However, this shouldn't be the case here.). If you find training times too long for your development cycle you can reduce the training set size. Once you have found a good solution you can increase the size again. Caveat: model parameters tuned on a smaller dataset may not be optimal for a larger training set.
# * In addition to this, as your submission is capped by size, feel free to experiment with different model sizes, numeric values of different precisions, filtering the vocabulary size, downscaling some vectors, etc.

# %% [markdown]
# ## Hints
#
# A non-exhaustive list of things you might want to give a try:
# - better tokenization
# - experiment with pre-trained word representations such as [word2vec](https://code.google.com/archive/p/word2vec/), or [GloVe](http://nlp.stanford.edu/projects/glove/). Be aware that these representations might take a lot of parameters in your model. Be sure you use only the words you expect in the training/dev set and account for OOV words. When saving the model parameters, pre-rained word embeddings can simply be used in the word embedding matrix of your model. As said, make sure that this word embedding matrix does not contain all of word2vec or GloVe. Your submission is limited, and we will not allow uploading nor using the whole representations set (up to 3GB!)
# - reduced sizes of word representations
# - bucketing and batching (our implementation is deliberately not a good one!)
#   - make sure to draw random batches from the data! (we do not provide this in our code!)
# - better models:
#   - stacked RNNs (see tf.contrib.rnn.MultiRNNCell)
#   - bi-directional RNNs
#   - attention
#   - word-by-word attention
#   - conditional encoding
#   - get model inspirations from papers on [nlp.stanford.edu/projects/snli/](nlp.stanford.edu/projects/snli/)
#   - sequence-to-sequence encoder-decode architecture for producing the right ordering
# - better training procedure:
#   - different training algorithms
#   - dropout on the input and output embeddings (see tf.nn.dropout)
#   - L2 regularization (see tf.nn.l2_loss)
#   - gradient clipping (see tf.clip_by_value or tf.clip_by_norm)
# - model selection:
#   - early stopping
# - hyper-parameter optimization (e.g. random search or grid search (expensive!))
#     - initial learning rate
#     - dropout probability
#     - input and output size
#     - L2 regularization
#     - gradient clipping value
#     - batch size
#     - ...
# - post-processing
#   - for incorporating consistency constraints

# %% [markdown]
# ## Setup Instructions
# It is important that this file is placed in the **correct directory**. It will not run otherwise. The correct directory is
#
#     DIRECTORY_OF_YOUR_BOOK/assignments/2017/assignment3/problem/group_X/
#
# where `DIRECTORY_OF_YOUR_BOOK` is a placeholder for the directory you downloaded the book to, and in `X` in `group_X` contains the number of your group.
#
# After you placed it there, **rename the notebook file** to `group_X.ipynb`.
#
# The notebook is pre-set to save models in
#
#     DIRECTORY_OF_YOUR_BOOK/assignments/2017/assignment3/problem/group_X/model/
#
# Be sure not to tinker with that directory - we expect your submission to contain a `model` subdirectory with a single saved model!
# The saving procedure might overwrite the latest save, or not. Make sure you understand what it does, and upload only a single model! (for more details check tf.train.Saver)

# %% [markdown]
# ## General Instructions
# This notebook will be used by you to provide your solution, and by us to both assess your solution and enter your marks. It contains three types of sections:
#
# 1. **Setup** Sections: these sections set up code and resources for assessment. **Do not edit, move nor copy these cells**.
# 2. **Assessment** Sections: these sections are used for both evaluating the output of your code, and for markers to enter their marks. **Do not edit, move, nor copy these cells**.
# 3. **Task** Sections: these sections require your solutions. They may contain stub code, and you are expected to edit this code. For free text answers simply edit the markdown field.
#
# **If you edit, move or copy any of the setup, assessments and mark cells, you will be penalised with -20 points**.
#
# Note that you are free to **create additional notebook cells** within a task section.
#
# Please **do not share** this assignment nor the dataset publicly, by uploading it online, emailing it to friends etc.

# %% [markdown]
# ## Submission Instructions
#
# To submit your solution:
#
# * Make sure that your solution is fully contained in this notebook. Make sure you do not use any additional files other than your saved model.
# * Make sure that your solution runs linearly from start to end (no execution hops). We will run your notebook in that order.
# * **Before you submit, make sure your submission is tested on the stat-nlp-book Docker setup to ensure that it does not have any dependencies outside of those that we provide. If your submission fails to adhere to this requirement, you will get 0 points**.
# * **If running your notebook produces a trivially fixable error that we spot, we will correct it and penalise you with -20 points. Otherwise you will get 0 points for that solution.**
# * **Rename this notebook to your `group_X`** (where `X` is the number of your group), and adhere to the directory structure requirements, if you have not already done so. ** Failure to do so will result in -1 point.**
# * Download the notebook in Jupyter via *File -> Download as -> Notebook (.ipynb)*.
# * Your submission should be a zip file containing the `group_X` directory, containing `group_X.ipynb` notebook, and the `model` directory with the saved model
# * Upload that file to the Moodle submission site.

# %% [markdown]
# ## <font color='green'>Setup 1</font>: Load Libraries
# This cell loads libraries important for evaluation and assessment of your model. **Do not change, move or copy it.**

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#! SETUP 1 - DO NOT CHANGE, MOVE NOR COPY
import sys, os
_snlp_book_dir = "../../../../../"
sys.path.append(_snlp_book_dir)
# docker image contains tensorflow 0.10.0rc0. We will support execution of only that version!
import statnlpbook.nn as nn

import tensorflow as tf
import numpy as np
import tensorflow.contrib as keras

# %% [markdown]
# ## <font color='green'>Setup 2</font>: Load Training Data
#
# This cell loads the training data. **Do not edit the next cell, nor copy/duplicate it**. Instead refer to the variables in your own code, and slice and dice them as you see fit (but do not change their values).
# For example, no one stops you from introducing, in the corresponding task section, `my_train` and `my_dev` variables that split the data into different folds.

# %%
#! SETUP 2 - DO NOT CHANGE, MOVE NOR COPY
data_path = _snlp_book_dir + "data/nn/"
data_train = nn.load_corpus(data_path + "train.tsv")
data_dev = nn.load_corpus(data_path + "dev.tsv")
assert(len(data_train) == 45502)

# %% [markdown]
# ### Data Structures
#
# Notice that the data is loaded from tab-separated files. The files are easy to read, and we provide the loading functions that load it into a simple data structure. Feel free to check details of the loading.
#
# The data structure at hand is an array of dictionaries, each containing a `story` and the `order` entry. `story` is a list of strings, and `order` is a list of integer indices:

# %%
data_train[1]
# Out:
# {'order': [1, 0, 3, 4, 2],
#  'story': ["She didn't have a bike of her own.",
#   'Carrie had just learned how to ride a bike.',
#   'She got nervous on a hill and crashed into a wall.',
#   'The bike frame bent and Carrie got a deep gash on her leg.',
#   "Carrie would sneak rides on her sister's bike."]}

# %% [markdown]
# ## <font color='blue'>Task 1</font>: Model implementation
#
# Your primary task in this assignment is to implement a model that produces the right order of the sentences in the dataset.
#
# ### Preprocessing pipeline
#
# First, we construct a preprocessing pipeline, in our case `pipeline` function which takes care of:
# - out-of-vocabulary words
# - building a vocabulary (on the train set), and applying the same unaltered vocabulary on other sets (dev and test)
# - making sure that the length of input is the same for the train and dev/test sets (for fixed-sized models)
#
# You are free (and encouraged!) to do your own input processing function. Should you experiment with recurrent neural networks, you will find that you will need to do so.

# %%
def tokenize(input):
    return input.split(' ')

# %%
import re
def tokenize(input):
    token = re.compile("[\w]+(?=n't)|n't|'s|\'m|\'ll|[\w]+|[.?!;,:]")
    tokens = token.findall(input)
    return tokens

# %%
def newpipeline(data, vocab=None, max_sent_len_=None):
    is_ext_vocab = True
    if vocab is None:
        is_ext_vocab = False
        vocab = {'<PAD>': 0, '<OOV>': 1}

    max_sent_len = -1
    data_sentences = []
    data_orders = []
    data_length = []
    for instance in data:
        sents = []
        story_length = []
        for sentence in instance['story']:
            sent = []
            tokenized = tokenize(sentence)
            temp_length = np.shape(tokenized)[0]
            for token in tokenized:
                if not is_ext_vocab and token not in vocab:
                    vocab[token] = len(vocab)
                if token not in vocab:
                    token_id = vocab['<OOV>']
                else:
                    token_id = vocab[token]
                sent.append(token_id)
            if len(sent) > max_sent_len:
                max_sent_len = len(sent)
            sents.append(sent)
            story_length.append(temp_length)
        data_sentences.append(sents)
        data_orders.append(instance['order'])
        data_length.append(story_length)

    if max_sent_len_ is not None:
        max_sent_len = max_sent_len_
    out_sentences = np.full([len(data_sentences), 5, max_sent_len], vocab['<PAD>'], dtype=np.int32)

    for i, elem in enumerate(data_sentences):
        for j, sent in enumerate(elem):
            out_sentences[i, j, 0:len(sent)] = sent

    out_orders = np.array(data_orders, dtype=np.int32)
    out_length = np.array(data_length, dtype = np.int32)
    return out_sentences, out_orders, vocab, out_length

# %%
# convert train set to integer IDs
train_stories, train_orders, vocab,train_length = newpipeline(data_train[0:10000])

# %%
train_length.shape
# Out:
# (10000, 5)

# %%
def loadWord2Vec(filename):
    vocab = {}
    embd = []
    file = open(filename,'r')
    for line in file.readlines():
        row = line.strip().split(' ')
        for i,token in enumerate(row):
            if i == 0:
                vocab[row[i]] = len(vocab)
            else:
                embd.append(float(row[i]))
    print('Successfully load.')
    file.close()    
    return vocab,embd

# %%
import re
def tokenize(input):
    token = re.compile("[\w]+(?=n't)|n't|'s|\'m|\'ll|[\w]+|[.?!;,:]")
    tokens = token.findall(input)
    return tokens

# %%
def pipeline2(data,vocab=None,embd=None,max_sent_len_=None):
    is_ext_vocab = True
    if vocab is None and embd is None: 
        is_ext_vocab = False
        #load word2vect
        filename = 'word2vec.txt'
        vocab, vec = loadWord2Vec(filename)
        embd = np.array(vec,dtype=np.float32)
        embd = np.reshape(embd,(len(vocab),50))
    
    max_sent_len = -1
    data_sentences = []
    data_orders = []
    full_length = []
    for instance in data:
        sents = []
        story_length = []
        for sentence in instance['story']:
            sent = []
            tokenized = tokenize(sentence)
            temp_length = np.shape(tokenized)[0]
            for token in tokenized:
                token = token.lower()
                if not is_ext_vocab: #trainning set
                    token_id = vocab[token]
                elif token not in vocab:
                    token_id = vocab['<OOV>']
                else:
                    token_id = vocab[token]                 
                sent.append(token_id)
            if len(sent) > max_sent_len:
                max_sent_len = len(sent)
            sents.append(sent)
            story_length.append(temp_length)
        data_sentences.append(sents)
        data_orders.append(instance['order'])
        full_length.append(story_length)

    if max_sent_len_ is not None:
        max_sent_len = max_sent_len_
    out_sentences = np.full([len(data_sentences), 5, max_sent_len], vocab['<PAD>'], dtype=np.int32)

    for i, elem in enumerate(data_sentences):
        for j, sent in enumerate(elem):
            out_sentences[i, j, 0:len(sent)] = sent

    out_orders = np.array(data_orders, dtype=np.int32)
    #full_length = np.reshape(full_length,[-1])
    full_length = np.asmatrix(full_length)
    return out_sentences, out_orders, vocab, embd, full_length

# %%
train_stories, train_orders, vocab, embd, train_length= pipeline2(data_train)
# Out:
# Successfully load.

# %%
train_length.shape
# Out:
# (45502, 5)

# %% [markdown]
# You need to make sure that the `pipeline` function returns the necessary data for your computational graph feed - the required inputs in this case, as we will call this function to process your dev and test data. If you do not make sure that the same pipeline applied to the train set is applied to other datasets, your model may not work with that data!

# %%
# get the length of the longest sentence = 24
max_sent_len = train_stories.shape[2]

# convert dev set to integer IDs, based on the train vocabulary and max_sent_len
dev_stories, dev_orders, _ ,dev_length= newpipeline(data_dev, vocab=vocab, max_sent_len_=max_sent_len)
max_sent_len
# Out:
# 20

# %%
#Word Embedding
max_sent_len = train_stories.shape[2]
dev_stories, dev_orders, _, _ ,dev_length= pipeline2(data_dev, vocab=vocab, max_sent_len_=max_sent_len)

# %% [markdown]
# You can take a look at the result of the `pipeline` with the `show_data_instance` function to make sure that your data loaded correctly:

# %%
nn.show_data_instance(dev_stories, dev_orders, vocab, 155)
# Out:
# Input:
#  Story:
#   the manager decided to offer john the job .
#   during the interview he was very talkative and <OOV> .
#   he went to the interview very prepared and nicely dressed .
#   john was excited to have a job interview .
#   the manager of the company was really impressed by john 's comments .
#  Order:
#   [4 2 1 0 3]
#
# Desired story:
#   john was excited to have a job interview .
#   he went to the interview very prepared and nicely dressed .
#   during the interview he was very talkative and <OOV> .
#   the manager of the company was really impressed by john 's comments .
#   the manager decided to offer john the job .

# %% [markdown]
# ### Model
#
# The model we provide is a rudimentary, non-optimised model that essentially represents every word in a sentence with a fixed vector, sums these vectors up (per sentence) and puts a softmax at the end which aims to guess the order of sentences independently.
#
# First we define the model parameters:

# %%
#training parameter
num_hidden = 8
target_size = 5
vocab_size = len(vocab)
input_size = 50
timesteps = 5
num_layers = 2

# %% [markdown]
# and then we define the model

# %%
tf.reset_default_graph()
#creat tensor holder
story = tf.placeholder(tf.int32, [None,None,None],"story")
order = tf.placeholder(tf.int32, [None,None],"order")
length = tf.placeholder(tf.int64, [None, None], "sentence_length") #[batch_size x 5]

weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, target_size]),dtype=tf.float32)
}
biases = {
    'out': tf.Variable(tf.random_normal([target_size]),dtype=tf.float32)
}

batch_size = tf.shape(story)[0]
sentences = [tf.reshape(x, [batch_size, -1]) for x in tf.split(axis=1, num_or_size_splits=5, value=story)]
#initializer = tf.random_uniform_initializer(-0.1, 0.1)
#embeddings = tf.get_variable("W", [vocab_size, input_size], initializer=initializer)

embeddings = tf.constant(embd)
sentences_embedded = [tf.nn.embedding_lookup(embeddings, sentence)    # 5 x batch_size x max_length x input_size
                    for sentence in sentences]
# hs = [tf.reduce_sum(sentence, 1) for sentence in sentences_embedded]
hs = []
#cell = tf.contrib.rnn.BasicLSTMCell(num_hidden, forget_bias=1.0,state_is_tuple=True)
hidden_units = [20,5]
rnn_layers = [tf.contrib.rnn.LSTMCell(size, activation= tf.nn.tanh) for size in hidden_units]
cell = tf.contrib.rnn.MultiRNNCell(rnn_layers, state_is_tuple=True)
cell = tf.contrib.rnn.DropoutWrapper(
      cell, output_keep_prob=0.4)


i = 0
for batch in sentences_embedded:
    output,final_state = tf.nn.dynamic_rnn(cell,batch,sequence_length = length[:,i],dtype=tf.float32)
    #output, _ = tf.nn.bidirectional_dynamic_rnn(cell_fw=cell,cell_bw=cell,inputs = batch, 
    #                                                      sequence_length= length[:,1], dtype = tf.float32)
    
    hs.append(final_state[-1].h)
    #hs.append(tf.matmul(final_state.h, weights['out']) + biases['out'])
    i+=1
# the size of hs [5,batch_size,5]

h = tf.concat(axis=1, values=hs)    # [batch_size x 5*input_size]
h = tf.reshape(h, [batch_size, 5*hidden_units[-1]])
logits_flat = tf.contrib.layers.linear(h, 5 * target_size)    # [batch_size x 5*target_size]
logits = tf.reshape(logits_flat, [-1, 5, target_size])        # [batch_size x 5 x target_size]
#logits = tf.transpose(hs,perm=[1,0,2])
# # # loss 
loss = tf.reduce_sum(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=order))

#beta = 0.1
#regularizers = tf.nn.l2_loss(weights['out'])

#loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
#    logits=logits, labels=order))

#loss = loss + beta * regularizers


# prediction function
unpacked_logits = [tensor for tensor in tf.unstack(logits, axis=1)]
softmaxes = [tf.nn.softmax(tensor) for tensor in unpacked_logits]
softmaxed_logits = tf.stack(softmaxes, axis=1)
predict = tf.arg_max(softmaxed_logits, 2)
#opt_op = tf.train.AdamOptimizer(0.1).minimize(loss)

# %%
max_gradient_norm = 1

# Calculate and clip gradients
params = tf.trainable_variables()
gradients = tf.gradients(loss, params)
clipped_gradients, _ = tf.clip_by_global_norm(
gradients, max_gradient_norm)

# Optimization
#optimizer = tf.train.AdamOptimizer(0.001)
optimizer = tf.train.RMSPropOptimizer(0.001)
update_step = optimizer.apply_gradients(
    zip(clipped_gradients, params))
opt_op = optimizer.minimize(loss)

# %%
1000//25
# Out:
# 40

# %%
tf.set_random_seed(1234)

# %% [markdown]
# We built our model, together with the loss and the prediction function, all we are left with now is to build an optimiser on the loss:

# %% [markdown]
# ### Model training
#
# We defined the preprocessing pipeline, set the model up, so we can finally train the model

# %%
np.random.choice(range(len(train_stories)),20,replace = False)
# Out:
# array([28803,   100, 40534, 34152,  9407, 40087, 17993, 30877, 43566,
#        14355,  7876, 10433, 42544, 21522,  8430, 43914, 36772, 34517,
#        23116, 24648])

# %%
BATCH_SIZE = 512
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    n = train_stories.shape[0]

    for epoch in range(1000):
        #BATCH_SIZE = 
        print('----- Epoch', epoch, '-----')
        total_loss = 0
        idx = np.random.permutation(train_stories.shape[0])
        for i in range(n // BATCH_SIZE):
            inst_story = train_stories[idx[i * BATCH_SIZE: (i + 1) * BATCH_SIZE]]
            inst_order = train_orders[idx[i * BATCH_SIZE: (i + 1) * BATCH_SIZE]]
            inst_length = train_length[idx[i * BATCH_SIZE: (i + 1) * BATCH_SIZE]]
            feed_dict = {story: inst_story, order: inst_order, length: inst_length}
            _, current_loss = sess.run([opt_op, loss], feed_dict=feed_dict)
            total_loss += current_loss

        print(' Train loss:', total_loss / n)

        train_feed_dict = {story: train_stories, order: train_orders, length: train_length}
        train_predicted = sess.run(predict, feed_dict=train_feed_dict)
        train_accuracy = nn.calculate_accuracy(train_orders, train_predicted)
        print(' Train accuracy:', train_accuracy)
        
        dev_feed_dict = {story: dev_stories, order: dev_orders,length:dev_length}
        dev_predicted = sess.run(predict, feed_dict=dev_feed_dict)
        dev_accuracy = nn.calculate_accuracy(dev_orders, dev_predicted)
        print(' Dev accuracy:', dev_accuracy)

        
    
    nn.save_model(sess)
# Out:
# ----- Epoch 0 -----
#  Train loss: 7.823172919
#  Train accuracy: 0.318073930816
#  Dev accuracy: 0.308818813469
# ----- Epoch 1 -----
#  Train loss: 7.21117543812
#  Train accuracy: 0.349615401521
#  Dev accuracy: 0.349011223944
# ----- Epoch 2 -----
#  Train loss: 6.84138643094
#  Train accuracy: 0.363346666081
#  Dev accuracy: 0.366862640299
# ----- Epoch 3 -----
#  Train loss: 6.66900403245
#  Train accuracy: 0.375390092743
#  Dev accuracy: 0.379155531801
# ----- Epoch 4 -----
#  Train loss: 6.55370595832
#  Train accuracy: 0.387481868929
#  Dev accuracy: 0.392089791555
# ----- Epoch 5 -----
#  Train loss: 6.45837628231
#  Train accuracy: 0.40535361083
#  Dev accuracy: 0.39914484233
# ----- Epoch 6 -----
#  Train loss: 6.36129633982
#  Train accuracy: 0.420021097974
#  Dev accuracy: 0.400962052378
# ----- Epoch 7 -----
#  Train loss: 6.25840915346
#  Train accuracy: 0.43580501956
#  Dev accuracy: 0.40833778728
# ----- Epoch 8 -----
#  Train loss: 6.15665607118
#  Train accuracy: 0.447386928047
#  Dev accuracy: 0.413682522715
# ----- Epoch 9 -----
#  Train loss: 6.06794314694
#  Train accuracy: 0.455320645246
#  Dev accuracy: 0.423837520043
# ----- Epoch 10 -----
#  Train loss: 5.98015338247
#  Train accuracy: 0.468304689904
#  Dev accuracy: 0.428113308391
# ----- Epoch 11 -----
#  Train loss: 5.90869896623
#  Train accuracy: 0.475847215507
#  Dev accuracy: 0.442544094067
# ----- Epoch 12 -----
#  Train loss: 5.84427316768
#  Train accuracy: 0.484202892181
#  Dev accuracy: 0.449278460716
# ----- Epoch 13 -----
#  Train loss: 5.78794574255
#  Train accuracy: 0.490299327502
#  Dev accuracy: 0.457936932122
# ----- Epoch 14 -----
#  Train loss: 5.73660005351
#  Train accuracy: 0.494228825107
#  Dev accuracy: 0.452912880812
# ----- Epoch 15 -----
#  Train loss: 5.69033268477
#  Train accuracy: 0.499824183552
#  Dev accuracy: 0.473222875468
# ----- Epoch 16 -----
#  Train loss: 5.65338302437
#  Train accuracy: 0.504496505648
#  Dev accuracy: 0.473650454303
# ----- Epoch 17 -----
#  Train loss: 5.61055551559
#  Train accuracy: 0.508953452595
#  Dev accuracy: 0.465098877606
# ----- Epoch 18 -----
#  Train loss: 5.57843295779
#  Train accuracy: 0.514636719265
#  Dev accuracy: 0.474184927846
# ----- Epoch 19 -----
#  Train loss: 5.54428179861
#  Train accuracy: 0.508034811657
#  Dev accuracy: 0.485622661678
# ----- Epoch 20 -----
#  Train loss: 5.5150644563
#  Train accuracy: 0.514386180827
#  Dev accuracy: 0.481560662747
# ----- Epoch 21 -----
#  Train loss: 5.49204208443
#  Train accuracy: 0.521893543141
#  Dev accuracy: 0.484553714591
# ----- Epoch 22 -----
#  Train loss: 5.46771422929
#  Train accuracy: 0.525335150103
#  Dev accuracy: 0.489898450027
# ----- Epoch 23 -----
#  Train loss: 5.44622737007
#  Train accuracy: 0.522856138192
#  Dev accuracy: 0.493532870123
# ----- Epoch 24 -----
#  Train loss: 5.42611439341
#  Train accuracy: 0.528157004088
#  Dev accuracy: 0.479529663282
# ----- Epoch 25 -----
#  Train loss: 5.40761755665
#  Train accuracy: 0.526341699266
#  Dev accuracy: 0.493105291288
# ----- Epoch 26 -----
#  Train loss: 5.39076222783
#  Train accuracy: 0.532877675707
#  Dev accuracy: 0.493319080706
# ----- Epoch 27 -----
#  Train loss: 5.37197031046
#  Train accuracy: 0.533471056217
#  Dev accuracy: 0.491822554784
# ----- Epoch 28 -----
#  Train loss: 5.35764662474
#  Train accuracy: 0.534855610742
#  Dev accuracy: 0.49877071085
# ----- Epoch 29 -----
#  Train loss: 5.34164175862
#  Train accuracy: 0.534539141137
#  Dev accuracy: 0.492891501871
# ----- Epoch 30 -----
#  Train loss: 5.32945356561
#  Train accuracy: 0.536855522834
#  Dev accuracy: 0.504222340994
# ----- Epoch 31 -----
#  Train loss: 5.31617076928
#  Train accuracy: 0.537475275812
#  Dev accuracy: 0.504649919829
# ----- Epoch 32 -----
#  Train loss: 5.30078528485
#  Train accuracy: 0.535558876533
#  Dev accuracy: 0.488508818813
# ----- Epoch 33 -----
#  Train loss: 5.290636891
#  Train accuracy: 0.538138982902
#  Dev accuracy: 0.500053447354
# ----- Epoch 34 -----
#  Train loss: 5.27981587369
#  Train accuracy: 0.541716847611
#  Dev accuracy: 0.501870657402
# ----- Epoch 35 -----
#  Train loss: 5.26882587557
#  Train accuracy: 0.543136565426
#  Dev accuracy: 0.506680919294
# ----- Epoch 36 -----
#  Train loss: 5.25707106946
#  Train accuracy: 0.543791481693
#  Dev accuracy: 0.507749866382
# ----- Epoch 37 -----
#  Train loss: 5.24860646364
#  Train accuracy: 0.541817942068
#  Dev accuracy: 0.494174238375
# ----- Epoch 38 -----
#  Train loss: 5.23588674888
#  Train accuracy: 0.545338666432
#  Dev accuracy: 0.50454302512
# ----- Epoch 39 -----
#  Train loss: 5.22870919586
#  Train accuracy: 0.546543009099
#  Dev accuracy: 0.509460181721
# ----- Epoch 40 -----
#  Train loss: 5.21755822761
#  Train accuracy: 0.547852841633
#  Dev accuracy: 0.507322287547
# ----- Epoch 41 -----
#  Train loss: 5.20816439902
#  Train accuracy: 0.547536372028
#  Dev accuracy: 0.515446285409
# ----- Epoch 42 -----
#  Train loss: 5.20031475909
#  Train accuracy: 0.548006681025
#  Dev accuracy: 0.498343132015
# ----- Epoch 43 -----
#  Train loss: 5.18644627099
#  Train accuracy: 0.550274713199
#  Dev accuracy: 0.514163548904
# ----- Epoch 44 -----
#  Train loss: 5.1825306743
#  Train accuracy: 0.548107775482
#  Dev accuracy: 0.512773917691
# ----- Epoch 45 -----
#  Train loss: 5.1772959821
#  Train accuracy: 0.550327458134
#  Dev accuracy: 0.508605024051
# ----- Epoch 46 -----
#  Train loss: 5.16457768383
#  Train accuracy: 0.549448375896
#  Dev accuracy: 0.502832709781
# ----- Epoch 47 -----
#  Train loss: 5.15954229819
#  Train accuracy: 0.552437255505
#  Dev accuracy: 0.509673971138
# ----- Epoch 48 -----
#  Train loss: 5.14644050674
#  Train accuracy: 0.551426310931
#  Dev accuracy: 0.517797969001
# ----- Epoch 49 -----
#  Train loss: 5.14531153743
#  Train accuracy: 0.553711924751
#  Dev accuracy: 0.511063602352
# ----- Epoch 50 -----
#  Train loss: 5.13919341157
#  Train accuracy: 0.55525910949
#  Dev accuracy: 0.512773917691
# ----- Epoch 51 -----
#  Train loss: 5.12688495642
#  Train accuracy: 0.554881104127
#  Dev accuracy: 0.512132549439
# ----- Epoch 52 -----
#  Train loss: 5.12224470173
#  Train accuracy: 0.551562568678
#  Dev accuracy: 0.505932656334
# ----- Epoch 53 -----
#  Train loss: 5.11496503802
#  Train accuracy: 0.554898685772
#  Dev accuracy: 0.516729021913
# ----- Epoch 54 -----
#  Train loss: 5.10964889764
#  Train accuracy: 0.554731660147
#  Dev accuracy: 0.510422234099
# ----- Epoch 55 -----
#  Train loss: 5.10135746308
#  Train accuracy: 0.553224034108
#  Dev accuracy: 0.504970603955
# ----- Epoch 56 -----
#  Train loss: 5.09512300799
#  Train accuracy: 0.557012878555
#  Dev accuracy: 0.516835916622
# ----- Epoch 57 -----
#  Train loss: 5.09380843021
#  Train accuracy: 0.557320557338
#  Dev accuracy: 0.511063602352
# ----- Epoch 58 -----
#  Train loss: 5.08663420379
#  Train accuracy: 0.555957979869
#  Dev accuracy: 0.521753073223
# ----- Epoch 59 -----
#  Train loss: 5.07956559173
#  Train accuracy: 0.559461122588
#  Dev accuracy: 0.511063602352
# ----- Epoch 60 -----
#  Train loss: 5.07615707161
#  Train accuracy: 0.560151202145
#  Dev accuracy: 0.518332442544
# ----- Epoch 61 -----
#  Train loss: 5.07057155669
#  Train accuracy: 0.560683046899
#  Dev accuracy: 0.521325494388
# ----- Epoch 62 -----
#  Train loss: 5.06227900611
#  Train accuracy: 0.558810601732
#  Dev accuracy: 0.520897915553
# ----- Epoch 63 -----
#  Train loss: 5.05845611976
#  Train accuracy: 0.560195156257
#  Dev accuracy: 0.522608230893
# ----- Epoch 64 -----
#  Train loss: 5.05213855856
#  Train accuracy: 0.562704936047
#  Dev accuracy: 0.518760021379
# ----- Epoch 65 -----
#  Train loss: 5.0515711041
#  Train accuracy: 0.56190497121
#  Dev accuracy: 0.520791020844
# ----- Epoch 66 -----
#  Train loss: 5.04537389625
#  Train accuracy: 0.561157751308
#  Dev accuracy: 0.515553180118
# ----- Epoch 67 -----
#  Train loss: 5.03856149717
#  Train accuracy: 0.56271812228
#  Dev accuracy: 0.521111704971
# ----- Epoch 68 -----
#  Train loss: 5.03489314773
#  Train accuracy: 0.562858775438
#  Dev accuracy: 0.515446285409
# ----- Epoch 69 -----
#  Train loss: 5.03232040496
#  Train accuracy: 0.560959957804
#  Dev accuracy: 0.516622127205
# ----- Epoch 70 -----
#  Train loss: 5.02673571096
#  Train accuracy: 0.558902905367
#  Dev accuracy: 0.524959914484
# ----- Epoch 71 -----
#  Train loss: 5.02274587196
#  Train accuracy: 0.563223594567
#  Dev accuracy: 0.519935863175
# ----- Epoch 72 -----
#  Train loss: 5.02050618676
#  Train accuracy: 0.564977363632
#  Dev accuracy: 0.522608230893
# ----- Epoch 73 -----
#  Train loss: 5.0159463286
#  Train accuracy: 0.564929014109
#  Dev accuracy: 0.520470336718
# ----- Epoch 74 -----
#  Train loss: 5.01177636465
#  Train accuracy: 0.562946683662
#  Dev accuracy: 0.522180652058
# ----- Epoch 75 -----
#  Train loss: 5.0077764117
#  Train accuracy: 0.565350973584
#  Dev accuracy: 0.519294494923
# ----- Epoch 76 -----
#  Train loss: 5.00618272102
#  Train accuracy: 0.566709155642
#  Dev accuracy: 0.521111704971
# ----- Epoch 77 -----
#  Train loss: 4.99963373541
#  Train accuracy: 0.565830073403
#  Dev accuracy: 0.519294494923
# ----- Epoch 78 -----
#  Train loss: 4.99844282686
#  Train accuracy: 0.567030020658
#  Dev accuracy: 0.522394441475
# ----- Epoch 79 -----
#  Train loss: 4.99432918449
#  Train accuracy: 0.564915827876
#  Dev accuracy: 0.524853019776
# ----- Epoch 80 -----
#  Train loss: 4.99155470458
#  Train accuracy: 0.567069579359
#  Dev accuracy: 0.521432389097
# ----- Epoch 81 -----
#  Train loss: 4.98599351681
#  Train accuracy: 0.567122324293
#  Dev accuracy: 0.523570283271
# ----- Epoch 82 -----
#  Train loss: 4.98328715183
#  Train accuracy: 0.563966419059
#  Dev accuracy: 0.52613575628
# ----- Epoch 83 -----
#  Train loss: 4.98097280043
#  Train accuracy: 0.568704672322
#  Dev accuracy: 0.523035809727
# ----- Epoch 84 -----
#  Train loss: 4.97599933794
#  Train accuracy: 0.568383807305
#  Dev accuracy: 0.523890967397
# ----- Epoch 85 -----
#  Train loss: 4.97610083696
#  Train accuracy: 0.568436552239
#  Dev accuracy: 0.523890967397
# ----- Epoch 86 -----
#  Train loss: 4.9714800429
#  Train accuracy: 0.565658652367
#  Dev accuracy: 0.514698022448
# ----- Epoch 87 -----
#  Train loss: 4.97308929351
#  Train accuracy: 0.568985978638
#  Dev accuracy: 0.523463388562
# ----- Epoch 88 -----
#  Train loss: 4.96623256473
#  Train accuracy: 0.569482660103
#  Dev accuracy: 0.525921966863
# ----- Epoch 89 -----
#  Train loss: 4.96528668748
#  Train accuracy: 0.566950903257
#  Dev accuracy: 0.52859433458
# ----- Epoch 90 -----
#  Train loss: 4.9614492982
#  Train accuracy: 0.570902377917
#  Dev accuracy: 0.523249599145
# ----- Epoch 91 -----
#  Train loss: 4.95799623377
#  Train accuracy: 0.570555140433
#  Dev accuracy: 0.525066809193
# ----- Epoch 92 -----
#  Train loss: 4.95519117592
#  Train accuracy: 0.568911256648
#  Dev accuracy: 0.521432389097
# ----- Epoch 93 -----
#  Train loss: 4.95256774535
#  Train accuracy: 0.570660630302
#  Dev accuracy: 0.521004810262
# ----- Epoch 94 -----
#  Train loss: 4.94883794492
#  Train accuracy: 0.570427673509
#  Dev accuracy: 0.520684126136
# ----- Epoch 95 -----
#  Train loss: 4.94896301991
#  Train accuracy: 0.571421036438
#  Dev accuracy: 0.52613575628
# ----- Epoch 96 -----
#  Train loss: 4.94540269392
#  Train accuracy: 0.56840138895
#  Dev accuracy: 0.525921966863
# ----- Epoch 97 -----
#  Train loss: 4.94262061111
#  Train accuracy: 0.570854028394
#  Dev accuracy: 0.529556386959
# ----- Epoch 98 -----
#  Train loss: 4.93844189069
#  Train accuracy: 0.571746296866
#  Dev accuracy: 0.525921966863
# ----- Epoch 99 -----
#  Train loss: 4.93801066072
#  Train accuracy: 0.566247637466
#  Dev accuracy: 0.514377338322
# ----- Epoch 100 -----
#  Train loss: 4.93839061805
#  Train accuracy: 0.570027691091
#  Dev accuracy: 0.527739176911
# ----- Epoch 101 -----
#  Train loss: 4.93217341301
#  Train accuracy: 0.572550657114
#  Dev accuracy: 0.526777124532
# ----- Epoch 102 -----
#  Train loss: 4.92929239052
#  Train accuracy: 0.572950639532
#  Dev accuracy: 0.526456440406
# ----- Epoch 103 -----
#  Train loss: 4.93175669669
#  Train accuracy: 0.573324249484
#  Dev accuracy: 0.527525387493
# ----- Epoch 104 -----
#  Train loss: 4.92376556873
#  Train accuracy: 0.572467144301
#  Dev accuracy: 0.525173703902
# ----- Epoch 105 -----
#  Train loss: 4.92269137037
#  Train accuracy: 0.571561689596
#  Dev accuracy: 0.520897915553
# ----- Epoch 106 -----
#  Train loss: 4.92220736541
#  Train accuracy: 0.573337435717
#  Dev accuracy: 0.523249599145
# ----- Epoch 107 -----
#  Train loss: 4.91834818151
#  Train accuracy: 0.572985802822
#  Dev accuracy: 0.530946018172
# ----- Epoch 108 -----
#  Train loss: 4.91833353372
#  Train accuracy: 0.573895652938
#  Dev accuracy: 0.524318546232
# ----- Epoch 109 -----
#  Train loss: 4.91320692935
#  Train accuracy: 0.574489033449
#  Dev accuracy: 0.525494388028
# ----- Epoch 110 -----
#  Train loss: 4.91053166276
#  Train accuracy: 0.573834117182
#  Dev accuracy: 0.523890967397
# ----- Epoch 111 -----
#  Train loss: 4.91246087912
#  Train accuracy: 0.574431893104
#  Dev accuracy: 0.527418492785
# ----- Epoch 112 -----
#  Train loss: 4.91099914199
#  Train accuracy: 0.574774735176
#  Dev accuracy: 0.527097808658
# ----- Epoch 113 -----
#  Train loss: 4.90740594163
#  Train accuracy: 0.574581337084
#  Dev accuracy: 0.523035809727
# ----- Epoch 114 -----
#  Train loss: 4.90675654002
#  Train accuracy: 0.575275812052
#  Dev accuracy: 0.52699091395
# ----- Epoch 115 -----
#  Train loss: 4.90297839651
#  Train accuracy: 0.574067073975
#  Dev accuracy: 0.525066809193
# ----- Epoch 116 -----
#  Train loss: 4.90208590054
#  Train accuracy: 0.574708804009
#  Dev accuracy: 0.526242650989
# ----- Epoch 117 -----
#  Train loss: 4.89679049779
#  Train accuracy: 0.572985802822
#  Dev accuracy: 0.523997862106
# ----- Epoch 118 -----
#  Train loss: 4.89420866588
#  Train accuracy: 0.575860401741
#  Dev accuracy: 0.526242650989
# ----- Epoch 119 -----
#  Train loss: 4.89341473937
#  Train accuracy: 0.574607709551
#  Dev accuracy: 0.527632282202
# ----- Epoch 120 -----
#  Train loss: 4.89367003485
#  Train accuracy: 0.573957188695
#  Dev accuracy: 0.524425440941
# ----- Epoch 121 -----
#  Train loss: 4.89517138541
#  Train accuracy: 0.576884532548
#  Dev accuracy: 0.530411544629
# ----- Epoch 122 -----
#  Train loss: 4.88789305235
#  Train accuracy: 0.57412421432
#  Dev accuracy: 0.523570283271
# ----- Epoch 123 -----
#  Train loss: 4.88835180193
#  Train accuracy: 0.574743967298
#  Dev accuracy: 0.532335649385
# ----- Epoch 124 -----
#  Train loss: 4.88558585852
#  Train accuracy: 0.573302272428
#  Dev accuracy: 0.521432389097
# ----- Epoch 125 -----
#  Train loss: 4.88549465052
#  Train accuracy: 0.575385697332
#  Dev accuracy: 0.524211651523
# ----- Epoch 126 -----
#  Train loss: 4.88154387766
#  Train accuracy: 0.575280207463
#  Dev accuracy: 0.532121859968
# ----- Epoch 127 -----
#  Train loss: 4.88049850273
#  Train accuracy: 0.576994417828
#  Dev accuracy: 0.52944949225
# ----- Epoch 128 -----
#  Train loss: 4.87852069646
#  Train accuracy: 0.576774647268
#  Dev accuracy: 0.52613575628
# ----- Epoch 129 -----
#  Train loss: 4.87746378035
#  Train accuracy: 0.577253747088
#  Dev accuracy: 0.529235702833
# ----- Epoch 130 -----
#  Train loss: 4.87436138839
#  Train accuracy: 0.575877983385
#  Dev accuracy: 0.525066809193
# ----- Epoch 131 -----
#  Train loss: 4.87264431285
#  Train accuracy: 0.577781196431
#  Dev accuracy: 0.523890967397
# ----- Epoch 132 -----
#  Train loss: 4.87422513172
#  Train accuracy: 0.577376818601
#  Dev accuracy: 0.532442544094
# ----- Epoch 133 -----
#  Train loss: 4.87050889526
#  Train accuracy: 0.576418618962
#  Dev accuracy: 0.52944949225
# ----- Epoch 134 -----
#  Train loss: 4.86787848954
#  Train accuracy: 0.57663399411
#  Dev accuracy: 0.524853019776
# ----- Epoch 135 -----
#  Train loss: 4.86533504773
#  Train accuracy: 0.577904267944
#  Dev accuracy: 0.533190807055
# ----- Epoch 136 -----
#  Train loss: 4.86514378403
#  Train accuracy: 0.574370357347
#  Dev accuracy: 0.527525387493
# ----- Epoch 137 -----
#  Train loss: 4.86717279319
#  Train accuracy: 0.578730605248
#  Dev accuracy: 0.527097808658
# ----- Epoch 138 -----
#  Train loss: 4.8631509222
#  Train accuracy: 0.578739396071
#  Dev accuracy: 0.529877071085
# ----- Epoch 139 -----
#  Train loss: 4.85989571028
#  Train accuracy: 0.575425256033
#  Dev accuracy: 0.530625334046
# ----- Epoch 140 -----
#  Train loss: 4.85854602609
#  Train accuracy: 0.577746033141
#  Dev accuracy: 0.524532335649
# ----- Epoch 141 -----
#  Train loss: 4.85906878063
#  Train accuracy: 0.578642697024
#  Dev accuracy: 0.524853019776
# ----- Epoch 142 -----
#  Train loss: 4.85723164147
#  Train accuracy: 0.576831787614
#  Dev accuracy: 0.527418492785
# ----- Epoch 143 -----
#  Train loss: 4.85424195168
#  Train accuracy: 0.579517383851
#  Dev accuracy: 0.533190807055
# ----- Epoch 144 -----
#  Train loss: 4.85148426576
#  Train accuracy: 0.57781635972
#  Dev accuracy: 0.533511491181
# ----- Epoch 145 -----
#  Train loss: 4.85267912867
#  Train accuracy: 0.579236077535
#  Dev accuracy: 0.527204703367
# ----- Epoch 146 -----
#  Train loss: 4.84838156796
#  Train accuracy: 0.57615489429
#  Dev accuracy: 0.529556386959
# ----- Epoch 147 -----
#  Train loss: 4.84858320316
#  Train accuracy: 0.57803613028
#  Dev accuracy: 0.526349545697
# ----- Epoch 148 -----
#  Train loss: 4.84742775515
#  Train accuracy: 0.579693200299
#  Dev accuracy: 0.530197755211
# ----- Epoch 149 -----
#  Train loss: 4.84489897723
#  Train accuracy: 0.579534965496
#  Dev accuracy: 0.53607696419
# ----- Epoch 150 -----
#  Train loss: 4.84385310866
#  Train accuracy: 0.57844050811
#  Dev accuracy: 0.525494388028
# ----- Epoch 151 -----
#  Train loss: 4.84355573699
#  Train accuracy: 0.579983297437
#  Dev accuracy: 0.533939070016
# ----- Epoch 152 -----
#  Train loss: 4.84027903628
#  Train accuracy: 0.580449211024
#  Dev accuracy: 0.533297701764
# ----- Epoch 153 -----
#  Train loss: 4.84156242982
#  Train accuracy: 0.579886598391
#  Dev accuracy: 0.533297701764
# ----- Epoch 154 -----
#  Train loss: 4.83751756233
#  Train accuracy: 0.580097578128
#  Dev accuracy: 0.531373597007
# ----- Epoch 155 -----
#  Train loss: 4.8354936182
#  Train accuracy: 0.578313041185
#  Dev accuracy: 0.527097808658
# ----- Epoch 156 -----
#  Train loss: 4.83584088358
#  Train accuracy: 0.577820755132
#  Dev accuracy: 0.529021913415
# ----- Epoch 157 -----
#  Train loss: 4.83611578457
#  Train accuracy: 0.580959078722
#  Dev accuracy: 0.531694281133
# ----- Epoch 158 -----
#  Train loss: 4.83294743998
#  Train accuracy: 0.580225045053
#  Dev accuracy: 0.533190807055
# ----- Epoch 159 -----
#  Train loss: 4.83197710145
#  Train accuracy: 0.581306316206
#  Dev accuracy: 0.535649385355
# ----- Epoch 160 -----
#  Train loss: 4.83169643256
#  Train accuracy: 0.580660190761
#  Dev accuracy: 0.527952966328
# ----- Epoch 161 -----
#  Train loss: 4.83139304617
#  Train accuracy: 0.581398619841
#  Dev accuracy: 0.532335649385
# ----- Epoch 162 -----
#  Train loss: 4.82718261569
#  Train accuracy: 0.58143378313
#  Dev accuracy: 0.535649385355
# ----- Epoch 163 -----
#  Train loss: 4.82862078221
#  Train accuracy: 0.580963474133
#  Dev accuracy: 0.529663281668
# ----- Epoch 164 -----
#  Train loss: 4.82658046796
#  Train accuracy: 0.579829458046
#  Dev accuracy: 0.534794227686
# ----- Epoch 165 -----
#  Train loss: 4.82529144066
#  Train accuracy: 0.581196430926
#  Dev accuracy: 0.532335649385
# ----- Epoch 166 -----
#  Train loss: 4.82333413057
#  Train accuracy: 0.581038196123
#  Dev accuracy: 0.528380545163
# ----- Epoch 167 -----
#  Train loss: 4.82499266323
#  Train accuracy: 0.580247022109
#  Dev accuracy: 0.527632282202
# ----- Epoch 168 -----
#  Train loss: 4.8210449809
#  Train accuracy: 0.580528328425
#  Dev accuracy: 0.532014965259
# ----- Epoch 169 -----
#  Train loss: 4.82106223095
#  Train accuracy: 0.581323897851
#  Dev accuracy: 0.535221806521
# ----- Epoch 170 -----
#  Train loss: 4.81864669711
#  Train accuracy: 0.582497472639
#  Dev accuracy: 0.528915018707
# ----- Epoch 171 -----
#  Train loss: 4.81651055517
#  Train accuracy: 0.580923915432
#  Dev accuracy: 0.529021913415
# ----- Epoch 172 -----
#  Train loss: 4.81923980398
#  Train accuracy: 0.580022856138
#  Dev accuracy: 0.527846071619
# ----- Epoch 173 -----
#  Train loss: 4.81326479189
#  Train accuracy: 0.581310711617
#  Dev accuracy: 0.527204703367
# ----- Epoch 174 -----
#  Train loss: 4.8167735555
#  Train accuracy: 0.580673376994
#  Dev accuracy: 0.52613575628
# ----- Epoch 175 -----
#  Train loss: 4.81332652188
#  Train accuracy: 0.581715089447
#  Dev accuracy: 0.530625334046
# ----- Epoch 176 -----
#  Train loss: 4.81235867294
#  Train accuracy: 0.581337084084
#  Dev accuracy: 0.534687332977
# ----- Epoch 177 -----
#  Train loss: 4.81221826874
#  Train accuracy: 0.582989758692
#  Dev accuracy: 0.529770176376
# ----- Epoch 178 -----
#  Train loss: 4.80802985287
#  Train accuracy: 0.583051294449
#  Dev accuracy: 0.531801175842
# ----- Epoch 179 -----
#  Train loss: 4.8103339991
#  Train accuracy: 0.583376554877
#  Dev accuracy: 0.532656333511
# ----- Epoch 180 -----
#  Train loss: 4.80584554491
#  Train accuracy: 0.581908487539
#  Dev accuracy: 0.534045964725
# ----- Epoch 181 -----
#  Train loss: 4.80647622095
#  Train accuracy: 0.583090853149
#  Dev accuracy: 0.532656333511
# ----- Epoch 182 -----
#  Train loss: 4.80519459803
#  Train accuracy: 0.583266669597
#  Dev accuracy: 0.537894174238
# ----- Epoch 183 -----
#  Train loss: 4.80544435633
#  Train accuracy: 0.581464551009
#  Dev accuracy: 0.527418492785
# ----- Epoch 184 -----
#  Train loss: 4.80592928951
#  Train accuracy: 0.583249087952
#  Dev accuracy: 0.535970069482
# ----- Epoch 185 -----
#  Train loss: 4.80518851893
#  Train accuracy: 0.583547975913
#  Dev accuracy: 0.53361838589
# ----- Epoch 186 -----
#  Train loss: 4.80184798496
#  Train accuracy: 0.583882027164
#  Dev accuracy: 0.535008017103
# ----- Epoch 187 -----
#  Train loss: 4.80310451348
#  Train accuracy: 0.582602962507
#  Dev accuracy: 0.537573490112
# ----- Epoch 188 -----
#  Train loss: 4.79867311593
#  Train accuracy: 0.584145751835
#  Dev accuracy: 0.531052912881
# ----- Epoch 189 -----
#  Train loss: 4.7967668907
#  Train accuracy: 0.584189705947
#  Dev accuracy: 0.531373597007
# ----- Epoch 190 -----
#  Train loss: 4.79846888384
#  Train accuracy: 0.583956749154
#  Dev accuracy: 0.535863174773
# ----- Epoch 191 -----
#  Train loss: 4.79620024107
#  Train accuracy: 0.583657861193
#  Dev accuracy: 0.532228754677
# ----- Epoch 192 -----
#  Train loss: 4.79584308708
#  Train accuracy: 0.581363456551
#  Dev accuracy: 0.536397648316
# ----- Epoch 193 -----
#  Train loss: 4.79644063122
#  Train accuracy: 0.58054591007
#  Dev accuracy: 0.527418492785
# ----- Epoch 194 -----
#  Train loss: 4.79300982284
#  Train accuracy: 0.584405081095
#  Dev accuracy: 0.53115980759
# ----- Epoch 195 -----
#  Train loss: 4.79352315558
#  Train accuracy: 0.583974330799
#  Dev accuracy: 0.530518439337
# ----- Epoch 196 -----
#  Train loss: 4.79247630513
#  Train accuracy: 0.583218320074
#  Dev accuracy: 0.536611437734
# ----- Epoch 197 -----
#  Train loss: 4.79144531508
#  Train accuracy: 0.583345786998
#  Dev accuracy: 0.531480491716
# ----- Epoch 198 -----
#  Train loss: 4.79115649063
#  Train accuracy: 0.585539097183
#  Dev accuracy: 0.536397648316
# ----- Epoch 199 -----
#  Train loss: 4.79218449211
#  Train accuracy: 0.58542042108
#  Dev accuracy: 0.53361838589
# ----- Epoch 200 -----
#  Train loss: 4.78879773442
#  Train accuracy: 0.585609423762
#  Dev accuracy: 0.532335649385
# ----- Epoch 201 -----
#  Train loss: 4.78838666261
#  Train accuracy: 0.584242450881
#  Dev accuracy: 0.532335649385
# ----- Epoch 202 -----
#  Train loss: 4.78684794676
#  Train accuracy: 0.585125928531
#  Dev accuracy: 0.535114911812
# ----- Epoch 203 -----
#  Train loss: 4.7864043064
#  Train accuracy: 0.585125928531
#  Dev accuracy: 0.534794227686
# ----- Epoch 204 -----
#  Train loss: 4.78410292877
#  Train accuracy: 0.585059997363
#  Dev accuracy: 0.535649385355
# ----- Epoch 205 -----
#  Train loss: 4.78327900379
#  Train accuracy: 0.584761109402
#  Dev accuracy: 0.539070016034
# ----- Epoch 206 -----
#  Train loss: 4.78266019085
#  Train accuracy: 0.58578963562
#  Dev accuracy: 0.534687332977
# ----- Epoch 207 -----
#  Train loss: 4.78239382635
#  Train accuracy: 0.585956661246
#  Dev accuracy: 0.533832175307
# ----- Epoch 208 -----
#  Train loss: 4.78014615193
#  Train accuracy: 0.585556678827
#  Dev accuracy: 0.535008017103
# ----- Epoch 209 -----
#  Train loss: 4.78237784792
#  Train accuracy: 0.584774295635
#  Dev accuracy: 0.533190807055
# ----- Epoch 210 -----
#  Train loss: 4.7789501247
#  Train accuracy: 0.58272603402
#  Dev accuracy: 0.539711384286
# ----- Epoch 211 -----
#  Train loss: 4.78257705255
#  Train accuracy: 0.585433607314
#  Dev accuracy: 0.531908070551
# ----- Epoch 212 -----
#  Train loss: 4.77961230692
#  Train accuracy: 0.584264427937
#  Dev accuracy: 0.531266702298
# ----- Epoch 213 -----
#  Train loss: 4.77958947675
#  Train accuracy: 0.585499538482
#  Dev accuracy: 0.537145911277
# ----- Epoch 214 -----
#  Train loss: 4.77627808814
#  Train accuracy: 0.586075337348
#  Dev accuracy: 0.535114911812
# ----- Epoch 215 -----
#  Train loss: 4.77600720053
#  Train accuracy: 0.585473166015
#  Dev accuracy: 0.538642437199
# ----- Epoch 216 -----
#  Train loss: 4.7769143282
#  Train accuracy: 0.584154542657
#  Dev accuracy: 0.532014965259
# ----- Epoch 217 -----
#  Train loss: 4.77377698006
#  Train accuracy: 0.586422574832
#  Dev accuracy: 0.535649385355
# ----- Epoch 218 -----
#  Train loss: 4.77403594017
#  Train accuracy: 0.582954595402
#  Dev accuracy: 0.529235702833
# ----- Epoch 219 -----
#  Train loss: 4.77373260744
#  Train accuracy: 0.583675442838
#  Dev accuracy: 0.529770176376
# ----- Epoch 220 -----
#  Train loss: 4.77110722919
#  Train accuracy: 0.58338974111
#  Dev accuracy: 0.529663281668
# ----- Epoch 221 -----
#  Train loss: 4.77004634261
#  Train accuracy: 0.585495143071
#  Dev accuracy: 0.53276322822
# ----- Epoch 222 -----
#  Train loss: 4.77252755009
#  Train accuracy: 0.585183068876
#  Dev accuracy: 0.533939070016
# ----- Epoch 223 -----
#  Train loss: 4.77277134732
#  Train accuracy: 0.58453254802
#  Dev accuracy: 0.535970069482
# ----- Epoch 224 -----
#  Train loss: 4.76933433107
#  Train accuracy: 0.58608412817
#  Dev accuracy: 0.53693212186
# ----- Epoch 225 -----
#  Train loss: 4.76874722819
#  Train accuracy: 0.58737637906
#  Dev accuracy: 0.532549438803
# ----- Epoch 226 -----
#  Train loss: 4.76534749138
#  Train accuracy: 0.582523845106
#  Dev accuracy: 0.527097808658
# ----- Epoch 227 -----
#  Train loss: 4.76528142607
#  Train accuracy: 0.584928135027
#  Dev accuracy: 0.530625334046
# ----- Epoch 228 -----
#  Train loss: 4.76602867817
#  Train accuracy: 0.585174278054
#  Dev accuracy: 0.536504543025
# ----- Epoch 229 -----
#  Train loss: 4.76479020453
#  Train accuracy: 0.586734649026
#  Dev accuracy: 0.535328701229
# ----- Epoch 230 -----
#  Train loss: 4.76455978347
#  Train accuracy: 0.585323722034
#  Dev accuracy: 0.529556386959
# ----- Epoch 231 -----
#  Train loss: 4.76601875201
#  Train accuracy: 0.585503933893
#  Dev accuracy: 0.531587386424
# ----- Epoch 232 -----
#  Train loss: 4.76157103263
#  Train accuracy: 0.587020350754
#  Dev accuracy: 0.532228754677
# ----- Epoch 233 -----
#  Train loss: 4.76343346472
#  Train accuracy: 0.584356731572
#  Dev accuracy: 0.536825227151
# ----- Epoch 234 -----
#  Train loss: 4.76093139085
#  Train accuracy: 0.587029141576
#  Dev accuracy: 0.537680384821
# ----- Epoch 235 -----
#  Train loss: 4.76070270284
#  Train accuracy: 0.585156696409
#  Dev accuracy: 0.530518439337
# ----- Epoch 236 -----
#  Train loss: 4.76036390957
#  Train accuracy: 0.587609335853
#  Dev accuracy: 0.534045964725
# ----- Epoch 237 -----
#  Train loss: 4.76115322176
#  Train accuracy: 0.587112654389
#  Dev accuracy: 0.536825227151
# ----- Epoch 238 -----
#  Train loss: 4.7558808316
#  Train accuracy: 0.587328029537
#  Dev accuracy: 0.535114911812
# ----- Epoch 239 -----
#  Train loss: 4.75781738796
#  Train accuracy: 0.587543404686
#  Dev accuracy: 0.53693212186
# ----- Epoch 240 -----
#  Train loss: 4.75801385619
#  Train accuracy: 0.585961056657
#  Dev accuracy: 0.532656333511
# ----- Epoch 241 -----
#  Train loss: 4.75405811489
#  Train accuracy: 0.587692848666
#  Dev accuracy: 0.53607696419
# ----- Epoch 242 -----
#  Train loss: 4.75608115762
#  Train accuracy: 0.587095072744
#  Dev accuracy: 0.535435595938
# ----- Epoch 243 -----
#  Train loss: 4.75537902931
#  Train accuracy: 0.58737637906
#  Dev accuracy: 0.537680384821
# ----- Epoch 244 -----
#  Train loss: 4.75493893018
#  Train accuracy: 0.587635708321
#  Dev accuracy: 0.531908070551
# ----- Epoch 245 -----
#  Train loss: 4.75402740281
#  Train accuracy: 0.58814997143
#  Dev accuracy: 0.536290753608
# ----- Epoch 246 -----
#  Train loss: 4.75164309613
#  Train accuracy: 0.58505120654
#  Dev accuracy: 0.531694281133
# ----- Epoch 247 -----
#  Train loss: 4.75339967242
#  Train accuracy: 0.58759614962
#  Dev accuracy: 0.539070016034
# ----- Epoch 248 -----
#  Train loss: 4.75283523874
#  Train accuracy: 0.588070854028
#  Dev accuracy: 0.534259754142
# ----- Epoch 249 -----
#  Train loss: 4.75042134674
#  Train accuracy: 0.584066634434
#  Dev accuracy: 0.539604489578
# ----- Epoch 250 -----
#  Train loss: 4.74987243542
#  Train accuracy: 0.587371983649
#  Dev accuracy: 0.531908070551
# ----- Epoch 251 -----
#  Train loss: 4.74989359156
#  Train accuracy: 0.586233572151
#  Dev accuracy: 0.533297701764
# ----- Epoch 252 -----
#  Train loss: 4.74837941747
#  Train accuracy: 0.587389565294
#  Dev accuracy: 0.541635489043
# ----- Epoch 253 -----
#  Train loss: 4.74475944867
#  Train accuracy: 0.588396114457
#  Dev accuracy: 0.536183858899
# ----- Epoch 254 -----
#  Train loss: 4.7494752656
#  Train accuracy: 0.588092831084
#  Dev accuracy: 0.533511491181
# ----- Epoch 255 -----
#  Train loss: 4.74655210253
#  Train accuracy: 0.588119203551
#  Dev accuracy: 0.534045964725
# ----- Epoch 256 -----
#  Train loss: 4.74685559623
#  Train accuracy: 0.588651048306
#  Dev accuracy: 0.535221806521
# ----- Epoch 257 -----
#  Train loss: 4.74586080179
#  Train accuracy: 0.587622522087
#  Dev accuracy: 0.533404596472
# ----- Epoch 258 -----
#  Train loss: 4.7468078058
#  Train accuracy: 0.588360951167
#  Dev accuracy: 0.533404596472
# ----- Epoch 259 -----
#  Train loss: 4.74607237924
#  Train accuracy: 0.588246670476
#  Dev accuracy: 0.536611437734
# ----- Epoch 260 -----
#  Train loss: 4.7429414375
#  Train accuracy: 0.5883345787
#  Dev accuracy: 0.539711384286
# ----- Epoch 261 -----
#  Train loss: 4.74269318691
#  Train accuracy: 0.588892795921
#  Dev accuracy: 0.537359700695
# ----- Epoch 262 -----
#  Train loss: 4.74281111506
#  Train accuracy: 0.587213748846
#  Dev accuracy: 0.535970069482
# ----- Epoch 263 -----
#  Train loss: 4.74007407556
#  Train accuracy: 0.58689727924
#  Dev accuracy: 0.531694281133
# ----- Epoch 264 -----
#  Train loss: 4.74044403697
#  Train accuracy: 0.588523581381
#  Dev accuracy: 0.536611437734
# ----- Epoch 265 -----
#  Train loss: 4.74144790446
#  Train accuracy: 0.58767087161
#  Dev accuracy: 0.542383752004
# ----- Epoch 266 -----
#  Train loss: 4.73653525983
#  Train accuracy: 0.588712584062
#  Dev accuracy: 0.535542490647
# ----- Epoch 267 -----
#  Train loss: 4.74107546955
#  Train accuracy: 0.588215902598
#  Dev accuracy: 0.52944949225
# ----- Epoch 268 -----
#  Train loss: 4.74053828721
#  Train accuracy: 0.588251065887
#  Dev accuracy: 0.533404596472
# ----- Epoch 269 -----
#  Train loss: 4.73372878012
#  Train accuracy: 0.588070854028
#  Dev accuracy: 0.534259754142
# ----- Epoch 270 -----
#  Train loss: 4.736355988
#  Train accuracy: 0.588796096875
#  Dev accuracy: 0.534152859433
# ----- Epoch 271 -----
#  Train loss: 4.73903019759
#  Train accuracy: 0.589152125181
#  Dev accuracy: 0.530839123463
# ----- Epoch 272 -----
#  Train loss: 4.73431937594
#  Train accuracy: 0.58907300778
#  Dev accuracy: 0.538321753073
# ----- Epoch 273 -----
#  Train loss: 4.73505836518
#  Train accuracy: 0.588084040262
#  Dev accuracy: 0.530197755211
# ----- Epoch 274 -----
#  Train loss: 4.73586791064
#  Train accuracy: 0.586488506
#  Dev accuracy: 0.53115980759
# ----- Epoch 275 -----
#  Train loss: 4.73499012149
#  Train accuracy: 0.588598303371
#  Dev accuracy: 0.541207910208
# ----- Epoch 276 -----
#  Train loss: 4.73233200837
#  Train accuracy: 0.588941145444
#  Dev accuracy: 0.539283805452
# ----- Epoch 277 -----
#  Train loss: 4.73391188291
#  Train accuracy: 0.588360951167
#  Dev accuracy: 0.539925173704
# ----- Epoch 278 -----
#  Train loss: 4.73281754249
#  Train accuracy: 0.589719133225
#  Dev accuracy: 0.540780331374
# ----- Epoch 279 -----
#  Train loss: 4.73099847431
#  Train accuracy: 0.58804008615
#  Dev accuracy: 0.537466595404
# ----- Epoch 280 -----
#  Train loss: 4.73051566586
#  Train accuracy: 0.589494967254
#  Dev accuracy: 0.536611437734
# ----- Epoch 281 -----
#  Train loss: 4.7294829052
#  Train accuracy: 0.589947694607
#  Dev accuracy: 0.535114911812
# ----- Epoch 282 -----
#  Train loss: 4.73106805938
#  Train accuracy: 0.58785547888
#  Dev accuracy: 0.531480491716
# ----- Epoch 283 -----
#  Train loss: 4.73021423788
#  Train accuracy: 0.588954331678
#  Dev accuracy: 0.538963121325
# ----- Epoch 284 -----
#  Train loss: 4.72658096802
#  Train accuracy: 0.588281833766
#  Dev accuracy: 0.541956173169
# ----- Epoch 285 -----
#  Train loss: 4.72857011694
#  Train accuracy: 0.588910377566
#  Dev accuracy: 0.542276857296
# ----- Epoch 286 -----
#  Train loss: 4.72835105462
#  Train accuracy: 0.590229000923
#  Dev accuracy: 0.537573490112
# ----- Epoch 287 -----
#  Train loss: 4.72925244658
#  Train accuracy: 0.585952265834
#  Dev accuracy: 0.532335649385
# ----- Epoch 288 -----
#  Train loss: 4.72740121764
#  Train accuracy: 0.590009230364
#  Dev accuracy: 0.536504543025
# ----- Epoch 289 -----
#  Train loss: 4.72479421084
#  Train accuracy: 0.58933233704
#  Dev accuracy: 0.537894174238
# ----- Epoch 290 -----
#  Train loss: 4.72244561687
#  Train accuracy: 0.589609247945
#  Dev accuracy: 0.532335649385
# ----- Epoch 291 -----
#  Train loss: 4.7245338396
#  Train accuracy: 0.589415849853
#  Dev accuracy: 0.539711384286
# ----- Epoch 292 -----
#  Train loss: 4.72422379464
#  Train accuracy: 0.588180739308
#  Dev accuracy: 0.543238909674
# ----- Epoch 293 -----
#  Train loss: 4.7224861478
#  Train accuracy: 0.589349918685
#  Dev accuracy: 0.538214858365
# ----- Epoch 294 -----
#  Train loss: 4.72374055158
#  Train accuracy: 0.590061975298
#  Dev accuracy: 0.535756280064
# ----- Epoch 295 -----
#  Train loss: 4.72216321492
#  Train accuracy: 0.589116961892
#  Dev accuracy: 0.534580438268
# ----- Epoch 296 -----
#  Train loss: 4.72226733767
#  Train accuracy: 0.589609247945
#  Dev accuracy: 0.534259754142
# ----- Epoch 297 -----
#  Train loss: 4.71919544316
#  Train accuracy: 0.590615797108
#  Dev accuracy: 0.537359700695
# ----- Epoch 298 -----
#  Train loss: 4.722867307
#  Train accuracy: 0.59007076612
#  Dev accuracy: 0.535435595938
# ----- Epoch 299 -----
#  Train loss: 4.72276446125
#  Train accuracy: 0.58988615885
#  Dev accuracy: 0.534152859433
# ----- Epoch 300 -----
#  Train loss: 4.71992571884
#  Train accuracy: 0.588273042943
#  Dev accuracy: 0.533297701764
# ----- Epoch 301 -----
#  Train loss: 4.71846083216
#  Train accuracy: 0.590703705332
#  Dev accuracy: 0.537359700695
# ----- Epoch 302 -----
#  Train loss: 4.72268219752
#  Train accuracy: 0.590760845677
#  Dev accuracy: 0.541207910208
# ----- Epoch 303 -----
#  Train loss: 4.71785648459
#  Train accuracy: 0.590817986023
#  Dev accuracy: 0.537894174238
# ----- Epoch 304 -----
#  Train loss: 4.71828489768
#  Train accuracy: 0.589525735133
#  Dev accuracy: 0.534152859433
# ----- Epoch 305 -----
#  Train loss: 4.71819379698
#  Train accuracy: 0.590677332864
#  Dev accuracy: 0.540887226082
# ----- Epoch 306 -----
#  Train loss: 4.71732475358
#  Train accuracy: 0.591037756582
#  Dev accuracy: 0.537359700695
# ----- Epoch 307 -----
#  Train loss: 4.71494662258
#  Train accuracy: 0.591042151993
#  Dev accuracy: 0.540352752539
# ----- Epoch 308 -----
#  Train loss: 4.71673238178
#  Train accuracy: 0.590418003604
#  Dev accuracy: 0.535649385355
# ----- Epoch 309 -----
#  Train loss: 4.7141137426
#  Train accuracy: 0.589051030724
#  Dev accuracy: 0.533832175307
# ----- Epoch 310 -----
#  Train loss: 4.7132096518
#  Train accuracy: 0.589688365347
#  Dev accuracy: 0.534901122394
# ----- Epoch 311 -----
#  Train loss: 4.71479405481
#  Train accuracy: 0.590628983341
#  Dev accuracy: 0.538001068947
# ----- Epoch 312 -----
#  Train loss: 4.71523715325
#  Train accuracy: 0.590963034592
#  Dev accuracy: 0.534687332977
# ----- Epoch 313 -----
#  Train loss: 4.71345209156
#  Train accuracy: 0.590039998242
#  Dev accuracy: 0.542169962587
# ----- Epoch 314 -----
#  Train loss: 4.71217307627
#  Train accuracy: 0.591261922553
#  Dev accuracy: 0.537359700695
# ----- Epoch 315 -----
#  Train loss: 4.71266855801
#  Train accuracy: 0.590672937453
#  Dev accuracy: 0.536183858899
# ----- Epoch 316 -----
#  Train loss: 4.71188897882
#  Train accuracy: 0.590721286976
#  Dev accuracy: 0.53778727953
# ----- Epoch 317 -----
#  Train loss: 4.71260897422
#  Train accuracy: 0.591112478572
#  Dev accuracy: 0.536825227151
# ----- Epoch 318 -----
#  Train loss: 4.71139041729
#  Train accuracy: 0.590989407059
#  Dev accuracy: 0.539176910743
# ----- Epoch 319 -----
#  Train loss: 4.71211396464
#  Train accuracy: 0.591116873984
#  Dev accuracy: 0.542063067878
# ----- Epoch 320 -----
#  Train loss: 4.70729735695
#  Train accuracy: 0.591609160037
#  Dev accuracy: 0.540887226082
# ----- Epoch 321 -----
#  Train loss: 4.71228437267
#  Train accuracy: 0.591130060217
#  Dev accuracy: 0.537359700695
# ----- Epoch 322 -----
#  Train loss: 4.70981719596
#  Train accuracy: 0.589925717551
#  Dev accuracy: 0.543025120257
# ----- Epoch 323 -----
#  Train loss: 4.71145895609
#  Train accuracy: 0.588110412729
#  Dev accuracy: 0.540780331374
# ----- Epoch 324 -----
#  Train loss: 4.70680509987
#  Train accuracy: 0.59110368775
#  Dev accuracy: 0.535114911812
# ----- Epoch 325 -----
#  Train loss: 4.70690833731
#  Train accuracy: 0.591341039954
#  Dev accuracy: 0.539604489578
# ----- Epoch 326 -----
#  Train loss: 4.70670686844
#  Train accuracy: 0.589323546218
#  Dev accuracy: 0.534580438268
# ----- Epoch 327 -----
#  Train loss: 4.70330004918
#  Train accuracy: 0.591499274757
#  Dev accuracy: 0.543345804383
# ----- Epoch 328 -----
#  Train loss: 4.70371251603
#  Train accuracy: 0.591595973803
#  Dev accuracy: 0.543773383218
# ----- Epoch 329 -----
#  Train loss: 4.70574501275
#  Train accuracy: 0.592004747044
#  Dev accuracy: 0.542490646713
# ----- Epoch 330 -----
#  Train loss: 4.7049141341
#  Train accuracy: 0.591297085842
#  Dev accuracy: 0.540138963121
# ----- Epoch 331 -----
#  Train loss: 4.7044691792
#  Train accuracy: 0.591749813195
#  Dev accuracy: 0.53939070016
# ----- Epoch 332 -----
#  Train loss: 4.70446246697
#  Train accuracy: 0.592189354314
#  Dev accuracy: 0.538107963656
# ----- Epoch 333 -----
#  Train loss: 4.706545791
#  Train accuracy: 0.592387147818
#  Dev accuracy: 0.537039016569
# ----- Epoch 334 -----
#  Train loss: 4.70121006657
#  Train accuracy: 0.586844534306
#  Dev accuracy: 0.528059861037
# ----- Epoch 335 -----
#  Train loss: 4.70146887109
#  Train accuracy: 0.590888312602
#  Dev accuracy: 0.541421699626
# ----- Epoch 336 -----
#  Train loss: 4.69904979065
#  Train accuracy: 0.591982769988
#  Dev accuracy: 0.539711384286
# ----- Epoch 337 -----
#  Train loss: 4.70170917539
#  Train accuracy: 0.592672849545
#  Dev accuracy: 0.541849278461
# ----- Epoch 338 -----
#  Train loss: 4.6975762548
#  Train accuracy: 0.58992132214
#  Dev accuracy: 0.540032068413
# ----- Epoch 339 -----
#  Train loss: 4.69869879088
#  Train accuracy: 0.591811348952
#  Dev accuracy: 0.535328701229
# ----- Epoch 340 -----
#  Train loss: 4.70159372073
#  Train accuracy: 0.592224517604
#  Dev accuracy: 0.538856226617
# ----- Epoch 341 -----
#  Train loss: 4.69857335104
#  Train accuracy: 0.592716803657
#  Dev accuracy: 0.540994120791
# ----- Epoch 342 -----
#  Train loss: 4.70071938695
#  Train accuracy: 0.592967342095
#  Dev accuracy: 0.542597541422
# ----- Epoch 343 -----
#  Train loss: 4.69739861945
#  Train accuracy: 0.590360863259
#  Dev accuracy: 0.532442544094
# ----- Epoch 344 -----
#  Train loss: 4.69857351737
#  Train accuracy: 0.592905806338
#  Dev accuracy: 0.537573490112
# ----- Epoch 345 -----
#  Train loss: 4.69760213257
#  Train accuracy: 0.592897015516
#  Dev accuracy: 0.54270443613
# ----- Epoch 346 -----
#  Train loss: 4.69834502789
#  Train accuracy: 0.592549778032
#  Dev accuracy: 0.539925173704
# ----- Epoch 347 -----
#  Train loss: 4.69708306413
#  Train accuracy: 0.59294976045
#  Dev accuracy: 0.539604489578
# ----- Epoch 348 -----
#  Train loss: 4.69399854999
#  Train accuracy: 0.590756450266
#  Dev accuracy: 0.533083912346
# ----- Epoch 349 -----
#  Train loss: 4.69306333933
#  Train accuracy: 0.592584941321
#  Dev accuracy: 0.54024585783
# ----- Epoch 350 -----
#  Train loss: 4.69420795442
#  Train accuracy: 0.592853061404
#  Dev accuracy: 0.537145911277
# ----- Epoch 351 -----
#  Train loss: 4.69397944347
#  Train accuracy: 0.591881675531
#  Dev accuracy: 0.53778727953
# ----- Epoch 352 -----
#  Train loss: 4.69153211908
#  Train accuracy: 0.593129972309
#  Dev accuracy: 0.538963121325
# ----- Epoch 353 -----
#  Train loss: 4.69256556116
#  Train accuracy: 0.592092655268
#  Dev accuracy: 0.537145911277
# ----- Epoch 354 -----
#  Train loss: 4.69432747075
#  Train accuracy: 0.59298492374
#  Dev accuracy: 0.537573490112
# ----- Epoch 355 -----
#  Train loss: 4.69088010984
#  Train accuracy: 0.592259680893
#  Dev accuracy: 0.539497594869
# ----- Epoch 356 -----
#  Train loss: 4.69429918388
#  Train accuracy: 0.591789371896
#  Dev accuracy: 0.537145911277
# ----- Epoch 357 -----
#  Train loss: 4.69031502693
#  Train accuracy: 0.592918992572
#  Dev accuracy: 0.53778727953
# ----- Epoch 358 -----
#  Train loss: 4.69390621523
#  Train accuracy: 0.593420069447
#  Dev accuracy: 0.539497594869
# ----- Epoch 359 -----
#  Train loss: 4.69306831315
#  Train accuracy: 0.592009142455
#  Dev accuracy: 0.53607696419
# ----- Epoch 360 -----
#  Train loss: 4.69076476249
#  Train accuracy: 0.590738868621
#  Dev accuracy: 0.535328701229
# ----- Epoch 361 -----
#  Train loss: 4.69129711052
#  Train accuracy: 0.592250890071
#  Dev accuracy: 0.537680384821
# ----- Epoch 362 -----
#  Train loss: 4.6879729574
#  Train accuracy: 0.592400334051
#  Dev accuracy: 0.544949225013
# ----- Epoch 363 -----
#  Train loss: 4.68756891975
#  Train accuracy: 0.593248648411
#  Dev accuracy: 0.53607696419
# ----- Epoch 364 -----
#  Train loss: 4.6867812333
#  Train accuracy: 0.593275020878
#  Dev accuracy: 0.537466595404
# ----- Epoch 365 -----
#  Train loss: 4.68682078235
#  Train accuracy: 0.591516856402
#  Dev accuracy: 0.539497594869
# ----- Epoch 366 -----
#  Train loss: 4.69046976236
#  Train accuracy: 0.593261834645
#  Dev accuracy: 0.543452699091
# ----- Epoch 367 -----
#  Train loss: 4.68478378934
#  Train accuracy: 0.588466441036
#  Dev accuracy: 0.537359700695
# ----- Epoch 368 -----
#  Train loss: 4.6855127451
#  Train accuracy: 0.593226671355
#  Dev accuracy: 0.538749331908
# ----- Epoch 369 -----
#  Train loss: 4.68831009274
#  Train accuracy: 0.593086018197
#  Dev accuracy: 0.53939070016
# ----- Epoch 370 -----
#  Train loss: 4.68630605458
#  Train accuracy: 0.592132213969
#  Dev accuracy: 0.535114911812
# ----- Epoch 371 -----
#  Train loss: 4.68553496361
#  Train accuracy: 0.592308030416
#  Dev accuracy: 0.538642437199
# ----- Epoch 372 -----
#  Train loss: 4.68410385271
#  Train accuracy: 0.594184870995
#  Dev accuracy: 0.540780331374
# ----- Epoch 373 -----
#  Train loss: 4.68520021592
#  Train accuracy: 0.594444200255
#  Dev accuracy: 0.5411010155
# ----- Epoch 374 -----
#  Train loss: 4.68527842333
#  Train accuracy: 0.593147553954
#  Dev accuracy: 0.539497594869
# ----- Epoch 375 -----
#  Train loss: 4.68224437701
#  Train accuracy: 0.593846424333
#  Dev accuracy: 0.539176910743
# ----- Epoch 376 -----
#  Train loss: 4.68433610877
#  Train accuracy: 0.594149707705
#  Dev accuracy: 0.540780331374
# ----- Epoch 377 -----
#  Train loss: 4.68236035212
#  Train accuracy: 0.59269043119
#  Dev accuracy: 0.5411010155
# ----- Epoch 378 -----
#  Train loss: 4.68295724703
#  Train accuracy: 0.594039822425
#  Dev accuracy: 0.539818278995
# ----- Epoch 379 -----
#  Train loss: 4.68268309721
#  Train accuracy: 0.594545294712
#  Dev accuracy: 0.541849278461
# ----- Epoch 380 -----
#  Train loss: 4.68360876265
#  Train accuracy: 0.594000263725
#  Dev accuracy: 0.538214858365
# ----- Epoch 381 -----
#  Train loss: 4.68196621916
#  Train accuracy: 0.593499186849
#  Dev accuracy: 0.537466595404
# ----- Epoch 382 -----
#  Train loss: 4.68133487779
#  Train accuracy: 0.594404641554
#  Dev accuracy: 0.541742383752
# ----- Epoch 383 -----
#  Train loss: 4.6797867777
#  Train accuracy: 0.594228825107
#  Dev accuracy: 0.544842330305
# ----- Epoch 384 -----
#  Train loss: 4.68028739958
#  Train accuracy: 0.592369566173
#  Dev accuracy: 0.542276857296
# ----- Epoch 385 -----
#  Train loss: 4.68062036593
#  Train accuracy: 0.593296997934
#  Dev accuracy: 0.538749331908
# ----- Epoch 386 -----
#  Train loss: 4.68214770157
#  Train accuracy: 0.594540899301
#  Dev accuracy: 0.539176910743
# ----- Epoch 387 -----
#  Train loss: 4.67941885517
#  Train accuracy: 0.593099204431
#  Dev accuracy: 0.546338856227
# ----- Epoch 388 -----
#  Train loss: 4.67813476949
#  Train accuracy: 0.593235462177
#  Dev accuracy: 0.543025120257
# ----- Epoch 389 -----
#  Train loss: 4.67689925224
#  Train accuracy: 0.594888136785
#  Dev accuracy: 0.539818278995
# ----- Epoch 390 -----
#  Train loss: 4.67836442328
#  Train accuracy: 0.5944617819
#  Dev accuracy: 0.538642437199
# ----- Epoch 391 -----
#  Train loss: 4.67964188795
#  Train accuracy: 0.592642081667
#  Dev accuracy: 0.542811330839
# ----- Epoch 392 -----
#  Train loss: 4.67659705699
#  Train accuracy: 0.594417827788
#  Dev accuracy: 0.540459647247
# ----- Epoch 393 -----
#  Train loss: 4.67848801203
#  Train accuracy: 0.592202540548
#  Dev accuracy: 0.53447354356
# ----- Epoch 394 -----
#  Train loss: 4.67816552449
#  Train accuracy: 0.594725506571
#  Dev accuracy: 0.541956173169
# ----- Epoch 395 -----
#  Train loss: 4.67689032943
#  Train accuracy: 0.594910113841
#  Dev accuracy: 0.5411010155
# ----- Epoch 396 -----
#  Train loss: 4.67691979134
#  Train accuracy: 0.592712408246
#  Dev accuracy: 0.537573490112
# ----- Epoch 397 -----
#  Train loss: 4.6762321445
#  Train accuracy: 0.592554173443
#  Dev accuracy: 0.542811330839
# ----- Epoch 398 -----
#  Train loss: 4.67716093802
#  Train accuracy: 0.59472111116
#  Dev accuracy: 0.540887226082
# ----- Epoch 399 -----
#  Train loss: 4.67413778365
#  Train accuracy: 0.594892532196
#  Dev accuracy: 0.542169962587
# ----- Epoch 400 -----
#  Train loss: 4.67403850595
#  Train accuracy: 0.595230978858
#  Dev accuracy: 0.540780331374
# ----- Epoch 401 -----
#  Train loss: 4.67375245546
#  Train accuracy: 0.594923300075
#  Dev accuracy: 0.536825227151
# ----- Epoch 402 -----
#  Train loss: 4.67288812296
#  Train accuracy: 0.594668366226
#  Dev accuracy: 0.540459647247
# ----- Epoch 403 -----
#  Train loss: 4.67386083304
#  Train accuracy: 0.595222188036
#  Dev accuracy: 0.540994120791
# ----- Epoch 404 -----
#  Train loss: 4.67186474654
#  Train accuracy: 0.593938727968
#  Dev accuracy: 0.543452699091
# ----- Epoch 405 -----
#  Train loss: 4.67078441543
#  Train accuracy: 0.594101358182
#  Dev accuracy: 0.5411010155
# ----- Epoch 406 -----
#  Train loss: 4.67030411266
#  Train accuracy: 0.594356292031
#  Dev accuracy: 0.538963121325
# ----- Epoch 407 -----
#  Train loss: 4.66968477927
#  Train accuracy: 0.594839787262
#  Dev accuracy: 0.540032068413
# ----- Epoch 408 -----
#  Train loss: 4.67093257276
#  Train accuracy: 0.595037580766
#  Dev accuracy: 0.540673436665
# ----- Epoch 409 -----
#  Train loss: 4.67029567811
#  Train accuracy: 0.594641993759
#  Dev accuracy: 0.53778727953
# ----- Epoch 410 -----
#  Train loss: 4.67021567326
#  Train accuracy: 0.595428772362
#  Dev accuracy: 0.543025120257
# ----- Epoch 411 -----
#  Train loss: 4.67146968536
#  Train accuracy: 0.595099116522
#  Dev accuracy: 0.539070016034
# ----- Epoch 412 -----
#  Train loss: 4.66894566126
#  Train accuracy: 0.595068348644
#  Dev accuracy: 0.539925173704
# ----- Epoch 413 -----
#  Train loss: 4.66701324169
#  Train accuracy: 0.593811261043
#  Dev accuracy: 0.542597541422
# ----- Epoch 414 -----
#  Train loss: 4.67000904815
#  Train accuracy: 0.593296997934
#  Dev accuracy: 0.543025120257
# ----- Epoch 415 -----
#  Train loss: 4.66872437226
#  Train accuracy: 0.594360687442
#  Dev accuracy: 0.539711384286
# ----- Epoch 416 -----
#  Train loss: 4.6683632961
#  Train accuracy: 0.595318887082
#  Dev accuracy: 0.542597541422
# ----- Epoch 417 -----
#  Train loss: 4.66777984712
#  Train accuracy: 0.594127730649
#  Dev accuracy: 0.538214858365
# ----- Epoch 418 -----
#  Train loss: 4.66609911742
#  Train accuracy: 0.593472814382
#  Dev accuracy: 0.538856226617
# ----- Epoch 419 -----
#  Train loss: 4.66576855482
#  Train accuracy: 0.595209001802
#  Dev accuracy: 0.542276857296
# ----- Epoch 420 -----
#  Train loss: 4.66510276699
#  Train accuracy: 0.596290272955
#  Dev accuracy: 0.542597541422
# ----- Epoch 421 -----
#  Train loss: 4.66507918029
#  Train accuracy: 0.595472726474
#  Dev accuracy: 0.543238909674
# ----- Epoch 422 -----
#  Train loss: 4.66524297266
#  Train accuracy: 0.595305700848
#  Dev accuracy: 0.536718332443
# ----- Epoch 423 -----
#  Train loss: 4.66528398649
#  Train accuracy: 0.595507889763
#  Dev accuracy: 0.539070016034
# ----- Epoch 424 -----
#  Train loss: 4.66365061799
#  Train accuracy: 0.596066106984
#  Dev accuracy: 0.5435595938
# ----- Epoch 425 -----
#  Train loss: 4.66701639124
#  Train accuracy: 0.595639752099
#  Dev accuracy: 0.542169962587
# ----- Epoch 426 -----
#  Train loss: 4.66481633019
#  Train accuracy: 0.595670519977
#  Dev accuracy: 0.540566541956
# ----- Epoch 427 -----
#  Train loss: 4.66468558388
#  Train accuracy: 0.596171596853
#  Dev accuracy: 0.543345804383
# ----- Epoch 428 -----
#  Train loss: 4.66207410762
#  Train accuracy: 0.59556942552
#  Dev accuracy: 0.543345804383
# ----- Epoch 429 -----
#  Train loss: 4.66410584781
#  Train accuracy: 0.59398268208
#  Dev accuracy: 0.545697487974
# ----- Epoch 430 -----
#  Train loss: 4.66161916217
#  Train accuracy: 0.595367236605
#  Dev accuracy: 0.545376803848
# ----- Epoch 431 -----
#  Train loss: 4.6609325455
#  Train accuracy: 0.594971649598
#  Dev accuracy: 0.538642437199
# ----- Epoch 432 -----
#  Train loss: 4.65933962746
#  Train accuracy: 0.594523317656
#  Dev accuracy: 0.542383752004
# ----- Epoch 433 -----
#  Train loss: 4.66179472644
#  Train accuracy: 0.595600193398
#  Dev accuracy: 0.5411010155
# ----- Epoch 434 -----
#  Train loss: 4.66150878327
# ...
#  Train accuracy: 0.604395411191
#  Dev accuracy: 0.540566541956
# ----- Epoch 856 -----
#  Train loss: 4.56710779883
#  Train accuracy: 0.60413608193
#  Dev accuracy: 0.546980224479
# ----- Epoch 857 -----
#  Train loss: 4.56800146984
#  Train accuracy: 0.603718517867
#  Dev accuracy: 0.539925173704
# ----- Epoch 858 -----
#  Train loss: 4.56685544364
#  Train accuracy: 0.603683354578
#  Dev accuracy: 0.542383752004
# ----- Epoch 859 -----
#  Train loss: 4.56638002347
#  Train accuracy: 0.604790998198
#  Dev accuracy: 0.545056119722
# ----- Epoch 860 -----
#  Train loss: 4.568112836
#  Train accuracy: 0.603788844446
#  Dev accuracy: 0.544094067344
# ----- Epoch 861 -----
#  Train loss: 4.5671106962
#  Train accuracy: 0.604672322096
#  Dev accuracy: 0.541207910208
# ----- Epoch 862 -----
#  Train loss: 4.5663907008
#  Train accuracy: 0.603300953804
#  Dev accuracy: 0.540566541956
# ----- Epoch 863 -----
#  Train loss: 4.56464772604
#  Train accuracy: 0.60450529647
#  Dev accuracy: 0.53939070016
# ----- Epoch 864 -----
#  Train loss: 4.56553892356
#  Train accuracy: 0.602685596238
#  Dev accuracy: 0.537466595404
# ----- Epoch 865 -----
#  Train loss: 4.56748049665
#  Train accuracy: 0.60557338139
#  Dev accuracy: 0.53939070016
# ----- Epoch 866 -----
#  Train loss: 4.56820654969
#  Train accuracy: 0.604922860534
#  Dev accuracy: 0.539818278995
# ----- Epoch 867 -----
#  Train loss: 4.56784665393
#  Train accuracy: 0.604672322096
#  Dev accuracy: 0.545697487974
# ----- Epoch 868 -----
#  Train loss: 4.56742509794
#  Train accuracy: 0.604988791701
#  Dev accuracy: 0.54270443613
# ----- Epoch 869 -----
#  Train loss: 4.56687006461
#  Train accuracy: 0.603982242539
#  Dev accuracy: 0.538963121325
# ----- Epoch 870 -----
#  Train loss: 4.5669255277
#  Train accuracy: 0.603837193969
#  Dev accuracy: 0.543987172635
# ----- Epoch 871 -----
#  Train loss: 4.56611726996
#  Train accuracy: 0.60398663795
#  Dev accuracy: 0.54687332977
# ----- Epoch 872 -----
#  Train loss: 4.56732377062
#  Train accuracy: 0.605270098018
#  Dev accuracy: 0.545911277392
# ----- Epoch 873 -----
#  Train loss: 4.56554441245
#  Train accuracy: 0.605305261307
#  Dev accuracy: 0.540780331374
# ----- Epoch 874 -----
#  Train loss: 4.56675626788
#  Train accuracy: 0.602830644807
#  Dev accuracy: 0.545590593266
# ----- Epoch 875 -----
#  Train loss: 4.56529418736
#  Train accuracy: 0.604918465122
#  Dev accuracy: 0.544200962052
# ----- Epoch 876 -----
#  Train loss: 4.56229810189
#  Train accuracy: 0.602922948442
#  Dev accuracy: 0.536504543025
# ----- Epoch 877 -----
#  Train loss: 4.56451121182
#  Train accuracy: 0.605261307195
#  Dev accuracy: 0.542811330839
# ----- Epoch 878 -----
#  Train loss: 4.56356682617
#  Train accuracy: 0.604478924003
#  Dev accuracy: 0.543666488509
# ----- Epoch 879 -----
#  Train loss: 4.56400494007
#  Train accuracy: 0.604993187113
#  Dev accuracy: 0.543345804383
# ----- Epoch 880 -----
#  Train loss: 4.56286375354
#  Train accuracy: 0.6049096743
#  Dev accuracy: 0.543773383218
# ----- Epoch 881 -----
#  Train loss: 4.56622620554
#  Train accuracy: 0.604395411191
#  Dev accuracy: 0.54441475147
# ----- Epoch 882 -----
#  Train loss: 4.56590060602
#  Train accuracy: 0.604483319415
#  Dev accuracy: 0.540459647247
# ----- Epoch 883 -----
#  Train loss: 4.56264620966
#  Train accuracy: 0.605076699925
#  Dev accuracy: 0.543238909674
# ----- Epoch 884 -----
#  Train loss: 4.56529615113
#  Train accuracy: 0.604522878115
#  Dev accuracy: 0.543880277926
# ----- Epoch 885 -----
#  Train loss: 4.56432681595
#  Train accuracy: 0.604175640631
#  Dev accuracy: 0.545590593266
# ----- Epoch 886 -----
#  Train loss: 4.5654484238
#  Train accuracy: 0.60450529647
#  Dev accuracy: 0.543238909674
# ----- Epoch 887 -----
#  Train loss: 4.56198969877
#  Train accuracy: 0.60531405213
#  Dev accuracy: 0.544307856761
# ----- Epoch 888 -----
#  Train loss: 4.5617960045
#  Train accuracy: 0.604852533955
#  Dev accuracy: 0.543238909674
# ----- Epoch 889 -----
#  Train loss: 4.56299228927
#  Train accuracy: 0.602940530087
#  Dev accuracy: 0.540566541956
# ----- Epoch 890 -----
#  Train loss: 4.56386362911
#  Train accuracy: 0.604738253264
#  Dev accuracy: 0.540994120791
# ----- Epoch 891 -----
#  Train loss: 4.56485280588
#  Train accuracy: 0.604747044086
#  Dev accuracy: 0.544307856761
# ----- Epoch 892 -----
#  Train loss: 4.56281934873
#  Train accuracy: 0.605164608149
#  Dev accuracy: 0.542169962587
# ----- Epoch 893 -----
#  Train loss: 4.56270151716
#  Train accuracy: 0.603920706782
#  Dev accuracy: 0.542383752004
# ----- Epoch 894 -----
#  Train loss: 4.56211651754
#  Train accuracy: 0.605340424597
#  Dev accuracy: 0.543238909674
# ----- Epoch 895 -----
#  Train loss: 4.56236377015
#  Train accuracy: 0.604747044086
#  Dev accuracy: 0.541849278461
# ----- Epoch 896 -----
#  Train loss: 4.56168416618
#  Train accuracy: 0.604623972573
#  Dev accuracy: 0.547835382149
# ----- Epoch 897 -----
#  Train loss: 4.5622389849
#  Train accuracy: 0.605863478528
#  Dev accuracy: 0.545163014431
# ----- Epoch 898 -----
#  Train loss: 4.56042675236
#  Train accuracy: 0.603854775614
#  Dev accuracy: 0.542276857296
# ----- Epoch 899 -----
#  Train loss: 4.56147105957
#  Train accuracy: 0.603744890334
#  Dev accuracy: 0.543880277926
# ----- Epoch 900 -----
#  Train loss: 4.56260117709
#  Train accuracy: 0.605476682344
#  Dev accuracy: 0.541207910208
# ----- Epoch 901 -----
#  Train loss: 4.56166950229
#  Train accuracy: 0.605032745813
#  Dev accuracy: 0.542383752004
# ----- Epoch 902 -----
#  Train loss: 4.56271966325
#  Train accuracy: 0.603991033361
#  Dev accuracy: 0.541207910208
# ----- Epoch 903 -----
#  Train loss: 4.55992298094
#  Train accuracy: 0.604773416553
#  Dev accuracy: 0.540887226082
# ----- Epoch 904 -----
#  Train loss: 4.56081186056
#  Train accuracy: 0.605823919828
#  Dev accuracy: 0.541314804917
# ----- Epoch 905 -----
#  Train loss: 4.56051807304
#  Train accuracy: 0.605749197837
#  Dev accuracy: 0.543025120257
# ----- Epoch 906 -----
#  Train loss: 4.56085011116
#  Train accuracy: 0.604659135862
#  Dev accuracy: 0.543666488509
# ----- Epoch 907 -----
#  Train loss: 4.56095445388
#  Train accuracy: 0.604843743132
#  Dev accuracy: 0.54024585783
# ----- Epoch 908 -----
#  Train loss: 4.56079207263
#  Train accuracy: 0.604694299152
#  Dev accuracy: 0.542169962587
# ----- Epoch 909 -----
#  Train loss: 4.56324115153
#  Train accuracy: 0.604637158806
#  Dev accuracy: 0.54441475147
# ----- Epoch 910 -----
#  Train loss: 4.55941326991
#  Train accuracy: 0.605208562261
#  Dev accuracy: 0.541635489043
# ----- Epoch 911 -----
#  Train loss: 4.56041618771
#  Train accuracy: 0.60439101578
#  Dev accuracy: 0.544735435596
# ----- Epoch 912 -----
#  Train loss: 4.5613551542
#  Train accuracy: 0.604544855171
#  Dev accuracy: 0.540566541956
# ----- Epoch 913 -----
#  Train loss: 4.55898248527
#  Train accuracy: 0.604711880796
#  Dev accuracy: 0.542490646713
# ----- Epoch 914 -----
#  Train loss: 4.55984683387
#  Train accuracy: 0.605063513692
#  Dev accuracy: 0.543345804383
# ----- Epoch 915 -----
#  Train loss: 4.56111660442
#  Train accuracy: 0.605511845633
#  Dev accuracy: 0.540138963121
# ----- Epoch 916 -----
#  Train loss: 4.56009752576
#  Train accuracy: 0.605375587886
#  Dev accuracy: 0.539604489578
# ----- Epoch 917 -----
#  Train loss: 4.56191751144
#  Train accuracy: 0.60583271065
#  Dev accuracy: 0.542169962587
# ----- Epoch 918 -----
#  Train loss: 4.55992508957
#  Train accuracy: 0.604900883478
#  Dev accuracy: 0.540138963121
# ----- Epoch 919 -----
#  Train loss: 4.56027723219
#  Train accuracy: 0.604632763395
#  Dev accuracy: 0.542063067878
# ----- Epoch 920 -----
#  Train loss: 4.5590172161
#  Train accuracy: 0.605362401653
#  Dev accuracy: 0.538963121325
# ----- Epoch 921 -----
#  Train loss: 4.55959122182
#  Train accuracy: 0.604738253264
#  Dev accuracy: 0.538535542491
# ----- Epoch 922 -----
#  Train loss: 4.55989885768
#  Train accuracy: 0.603815216914
#  Dev accuracy: 0.54441475147
# ----- Epoch 923 -----
#  Train loss: 4.55959387238
#  Train accuracy: 0.605081095336
#  Dev accuracy: 0.543880277926
# ----- Epoch 924 -----
#  Train loss: 4.56309932548
#  Train accuracy: 0.606056876621
#  Dev accuracy: 0.540352752539
# ----- Epoch 925 -----
#  Train loss: 4.55919316132
#  Train accuracy: 0.60358226012
#  Dev accuracy: 0.546980224479
# ----- Epoch 926 -----
#  Train loss: 4.55865477174
#  Train accuracy: 0.605107467804
#  Dev accuracy: 0.544307856761
# ----- Epoch 927 -----
#  Train loss: 4.56248617849
#  Train accuracy: 0.605437123643
#  Dev accuracy: 0.544628540887
# ----- Epoch 928 -----
#  Train loss: 4.55912207928
#  Train accuracy: 0.602026284559
#  Dev accuracy: 0.547835382149
# ----- Epoch 929 -----
#  Train loss: 4.55950533639
#  Train accuracy: 0.603186673113
#  Dev accuracy: 0.547407803314
# ----- Epoch 930 -----
#  Train loss: 4.55841105499
#  Train accuracy: 0.605823919828
#  Dev accuracy: 0.540459647247
# ----- Epoch 931 -----
#  Train loss: 4.55936832318
#  Train accuracy: 0.606166761901
#  Dev accuracy: 0.543345804383
# ----- Epoch 932 -----
#  Train loss: 4.55915221189
#  Train accuracy: 0.60516900356
#  Dev accuracy: 0.546338856227
# ----- Epoch 933 -----
#  Train loss: 4.55662276328
#  Train accuracy: 0.604892092655
#  Dev accuracy: 0.542490646713
# ----- Epoch 934 -----
#  Train loss: 4.55571528685
#  Train accuracy: 0.603933893016
#  Dev accuracy: 0.544735435596
# ----- Epoch 935 -----
#  Train loss: 4.55922017658
#  Train accuracy: 0.605920618874
#  Dev accuracy: 0.540780331374
# ----- Epoch 936 -----
#  Train loss: 4.55608338108
#  Train accuracy: 0.604250362621
#  Dev accuracy: 0.545269909139
# ----- Epoch 937 -----
#  Train loss: 4.55926519842
#  Train accuracy: 0.603854775614
#  Dev accuracy: 0.544094067344
# ----- Epoch 938 -----
#  Train loss: 4.55638404716
#  Train accuracy: 0.604729462441
#  Dev accuracy: 0.539711384286
# ----- Epoch 939 -----
#  Train loss: 4.55818525362
#  Train accuracy: 0.605661289614
#  Dev accuracy: 0.545056119722
# ----- Epoch 940 -----
#  Train loss: 4.55715858279
#  Train accuracy: 0.603375675794
#  Dev accuracy: 0.541207910208
# ----- Epoch 941 -----
#  Train loss: 4.55837208542
#  Train accuracy: 0.606096435322
#  Dev accuracy: 0.543666488509
# ----- Epoch 942 -----
#  Train loss: 4.55800590131
#  Train accuracy: 0.604839347721
#  Dev accuracy: 0.540566541956
# ----- Epoch 943 -----
#  Train loss: 4.5579686487
#  Train accuracy: 0.606228297657
#  Dev accuracy: 0.541742383752
# ----- Epoch 944 -----
#  Train loss: 4.55659321015
#  Train accuracy: 0.604900883478
#  Dev accuracy: 0.541207910208
# ----- Epoch 945 -----
#  Train loss: 4.55613684284
#  Train accuracy: 0.60439101578
#  Dev accuracy: 0.545056119722
# ----- Epoch 946 -----
#  Train loss: 4.55619482772
#  Train accuracy: 0.606338182937
#  Dev accuracy: 0.5411010155
# ----- Epoch 947 -----
#  Train loss: 4.55608397665
#  Train accuracy: 0.605837106061
#  Dev accuracy: 0.538428647782
# ----- Epoch 948 -----
#  Train loss: 4.55811531979
#  Train accuracy: 0.606100830733
#  Dev accuracy: 0.541635489043
# ----- Epoch 949 -----
#  Train loss: 4.55507595627
#  Train accuracy: 0.606267856358
#  Dev accuracy: 0.542918225548
# ----- Epoch 950 -----
#  Train loss: 4.55683863312
#  Train accuracy: 0.606056876621
#  Dev accuracy: 0.54270443613
# ----- Epoch 951 -----
#  Train loss: 4.55771380928
#  Train accuracy: 0.605674475847
#  Dev accuracy: 0.545590593266
# ----- Epoch 952 -----
#  Train loss: 4.55588816301
#  Train accuracy: 0.605933805107
#  Dev accuracy: 0.539711384286
# ----- Epoch 953 -----
#  Train loss: 4.55673292756
#  Train accuracy: 0.606443672806
#  Dev accuracy: 0.545590593266
# ----- Epoch 954 -----
#  Train loss: 4.55501497745
#  Train accuracy: 0.603859171025
#  Dev accuracy: 0.545376803848
# ----- Epoch 955 -----
#  Train loss: 4.55628911551
#  Train accuracy: 0.605819524417
#  Dev accuracy: 0.545697487974
# ----- Epoch 956 -----
#  Train loss: 4.55493737634
#  Train accuracy: 0.604707485385
#  Dev accuracy: 0.541314804917
# ----- Epoch 957 -----
#  Train loss: 4.55487201928
#  Train accuracy: 0.606272251769
#  Dev accuracy: 0.542490646713
# ----- Epoch 958 -----
#  Train loss: 4.5568053778
#  Train accuracy: 0.605916223463
#  Dev accuracy: 0.542383752004
# ----- Epoch 959 -----
#  Train loss: 4.55318127757
#  Train accuracy: 0.605212957672
#  Dev accuracy: 0.545269909139
# ----- Epoch 960 -----
#  Train loss: 4.55193574832
#  Train accuracy: 0.606390927871
#  Dev accuracy: 0.540780331374
# ----- Epoch 961 -----
#  Train loss: 4.55458053355
#  Train accuracy: 0.603450397785
#  Dev accuracy: 0.546338856227
# ----- Epoch 962 -----
#  Train loss: 4.55515403491
#  Train accuracy: 0.606228297657
#  Dev accuracy: 0.54441475147
# ----- Epoch 963 -----
#  Train loss: 4.55242718448
#  Train accuracy: 0.605432728232
#  Dev accuracy: 0.543773383218
# ----- Epoch 964 -----
#  Train loss: 4.55419021009
#  Train accuracy: 0.606298624236
#  Dev accuracy: 0.540673436665
# ----- Epoch 965 -----
#  Train loss: 4.55556641054
#  Train accuracy: 0.605599753857
#  Dev accuracy: 0.541742383752
# ----- Epoch 966 -----
#  Train loss: 4.5558213519
#  Train accuracy: 0.605714034548
#  Dev accuracy: 0.542169962587
# ----- Epoch 967 -----
#  Train loss: 4.55618826572
#  Train accuracy: 0.605788756538
#  Dev accuracy: 0.538535542491
# ----- Epoch 968 -----
#  Train loss: 4.55423684695
#  Train accuracy: 0.606329392115
#  Dev accuracy: 0.542490646713
# ----- Epoch 969 -----
#  Train loss: 4.55589164522
#  Train accuracy: 0.603208650169
#  Dev accuracy: 0.540887226082
# ----- Epoch 970 -----
#  Train loss: 4.55403015746
#  Train accuracy: 0.605599753857
#  Dev accuracy: 0.544200962052
# ----- Epoch 971 -----
#  Train loss: 4.55137446418
#  Train accuracy: 0.60631181047
#  Dev accuracy: 0.544094067344
# ----- Epoch 972 -----
#  Train loss: 4.5542072187
#  Train accuracy: 0.606012922509
#  Dev accuracy: 0.542597541422
# ----- Epoch 973 -----
#  Train loss: 4.55330595015
#  Train accuracy: 0.605661289614
#  Dev accuracy: 0.542276857296
# ----- Epoch 974 -----
#  Train loss: 4.55351194213
#  Train accuracy: 0.6030636016
#  Dev accuracy: 0.538642437199
# ----- Epoch 975 -----
#  Train loss: 4.55378534615
#  Train accuracy: 0.604865720188
#  Dev accuracy: 0.541742383752
# ----- Epoch 976 -----
#  Train loss: 4.55282782578
#  Train accuracy: 0.60623708848
#  Dev accuracy: 0.542811330839
# ----- Epoch 977 -----
#  Train loss: 4.5527407492
#  Train accuracy: 0.605850292295
#  Dev accuracy: 0.545056119722
# ----- Epoch 978 -----
#  Train loss: 4.55214996023
#  Train accuracy: 0.606390927871
#  Dev accuracy: 0.544521646179
# ----- Epoch 979 -----
#  Train loss: 4.55248557713
#  Train accuracy: 0.605437123643
#  Dev accuracy: 0.539818278995
# ----- Epoch 980 -----
#  Train loss: 4.55242237163
#  Train accuracy: 0.605964572986
#  Dev accuracy: 0.541207910208
# ----- Epoch 981 -----
#  Train loss: 4.55201117104
#  Train accuracy: 0.606452463628
#  Dev accuracy: 0.543452699091
# ----- Epoch 982 -----
#  Train loss: 4.55160852841
#  Train accuracy: 0.605151421916
#  Dev accuracy: 0.541421699626
# ----- Epoch 983 -----
#  Train loss: 4.55431758151
#  Train accuracy: 0.605494263988
#  Dev accuracy: 0.546125066809
# ----- Epoch 984 -----
#  Train loss: 4.55329511186
#  Train accuracy: 0.60609203991
#  Dev accuracy: 0.538428647782
# ----- Epoch 985 -----
#  Train loss: 4.55079715868
#  Train accuracy: 0.605753593249
#  Dev accuracy: 0.546552645644
# ----- Epoch 986 -----
#  Train loss: 4.55377843539
#  Train accuracy: 0.606259065536
#  Dev accuracy: 0.541207910208
# ----- Epoch 987 -----
#  Train loss: 4.5535078107
#  Train accuracy: 0.604883301833
#  Dev accuracy: 0.544949225013
# ----- Epoch 988 -----
#  Train loss: 4.55102312639
#  Train accuracy: 0.604905278889
#  Dev accuracy: 0.547942276857
# ----- Epoch 989 -----
#  Train loss: 4.55152669392
#  Train accuracy: 0.605551404334
#  Dev accuracy: 0.543452699091
# ----- Epoch 990 -----
#  Train loss: 4.55272838175
#  Train accuracy: 0.606531581029
#  Dev accuracy: 0.541635489043
# ----- Epoch 991 -----
#  Train loss: 4.55040461391
#  Train accuracy: 0.604232780977
#  Dev accuracy: 0.538321753073
# ----- Epoch 992 -----
#  Train loss: 4.54804584697
#  Train accuracy: 0.606509603973
#  Dev accuracy: 0.542169962587
# ----- Epoch 993 -----
#  Train loss: 4.5535863937
#  Train accuracy: 0.604105314052
#  Dev accuracy: 0.547835382149
# ----- Epoch 994 -----
#  Train loss: 4.54957900417
#  Train accuracy: 0.606105226144
#  Dev accuracy: 0.541314804917
# ----- Epoch 995 -----
#  Train loss: 4.55021494913
#  Train accuracy: 0.604922860534
#  Dev accuracy: 0.542276857296
# ----- Epoch 996 -----
#  Train loss: 4.54894324163
#  Train accuracy: 0.605898641818
#  Dev accuracy: 0.544842330305
# ----- Epoch 997 -----
#  Train loss: 4.55062469567
#  Train accuracy: 0.606615093842
#  Dev accuracy: 0.5435595938
# ----- Epoch 998 -----
#  Train loss: 4.55163007086
#  Train accuracy: 0.605010768757
#  Dev accuracy: 0.536183858899
# ----- Epoch 999 -----
#  Train loss: 4.55223700997
#  Train accuracy: 0.605428332821
#  Dev accuracy: 0.540138963121

# %% [markdown]
# ## <font color='red'>Assessment 1</font>: Assess Accuracy (40 pts)
#
# We assess how well your model performs on an unseen test set. We will look at the accuracy of the predicted sentence order, on sentence level, and will score them as followis:
#
# * 0 - 10 pts: 45% <= accuracy < 50%, linear
# * 10 - 20 pts: 50% <= accuracy < 55, linear
# * 20 - 40 pts: 55 <= accuracy < 60, linear
# * extra 0-10 pts: 60 <= accuracy < 70, linear
#
# The **linear** mapping maps any accuracy value between the lower and upper bound linearly to a score. For example, if your model's accuracy score is $acc=54.5\%$, then your score is $10 + 10\frac{acc-50}{55-50}$.

# %% [markdown]
# Change the following lines so that they construct the test set in the same way you constructed the dev set in the code above. We will insert the test set instead of the dev set here. **`test_feed_dict` variable must stay named the same**.

# %%
# LOAD THE DATA
data_test = nn.load_corpus(data_path + "dev.tsv")
# make sure you process this with the same pipeline as you processed your dev set
test_stories, test_orders, _ = nn.pipeline(data_test, vocab=vocab, max_sent_len_=max_sent_len)

# THIS VARIABLE MUST BE NAMED `test_feed_dict`
test_feed_dict = {story: test_stories, order: test_orders}

# %% [markdown]
# The following code loads your model, computes accuracy, and exports the result. **DO NOT** change this code.

# %%
#! ASSESSMENT 1 - DO NOT CHANGE, MOVE NOR COPY
with tf.Session() as sess:
    # LOAD THE MODEL
    saver = tf.train.Saver()
    saver.restore(sess, './model/model.checkpoint')
    
    # RUN TEST SET EVALUATION
    dev_predicted = sess.run(predict, feed_dict=test_feed_dict)
    dev_accuracy = nn.calculate_accuracy(dev_orders, dev_predicted)

dev_accuracy
# Out:
# 0.38995189738107966

# %% [markdown]
# ## <font color='orange'>Mark</font>:  Your solution to Task 1 is marked with ** __ points**.
# ---

# %% [markdown]
# ## <font color='blue'>Task 2</font>: Describe your Approach
#
# Enter a 1000 words max description of your approach **in this cell**.
# Make sure to provide:
# - an **error analysis** of the types of errors your system makes
# - compare your system with the model we provide, focus on differences and draw useful comparations between them
#
# Should you need to include figures in your report, make sure they are Python-generated (matplotlib, seaborn, bokeh are all included in the stat-nlp-book Docker image). For that, feel free to create new cells after this cell (before Assessment 2 cell). Link online images at your risk.

# %% [markdown]
# ...WRITE YOUR DESCRIPTION HERE...

# %% [markdown]
# ## <font color='red'>Assessment 2</font>: Assess Description (60 pts)
#
# We will mark the description along the following dimensions:
#
# * Clarity (10pts: very clear, 0pts: we can't figure out what you did, or you did nothing)
# * Creativity (25pts: we could not have come up with this, 0pts: Use only the provided model)
# * Substance (25pts: implemented complex state-of-the-art classifier, compared it to a simpler model, 0pts: Only use what is already there)

# %% [markdown]
# ## <font color='orange'>Mark</font>:  Your solution to Task 2 is marked with ** __ points**.
# ---

# %% [markdown]
# ## <font color='orange'>Final mark</font>: Your solution to Assignment 3 is marked with ** __points**.
